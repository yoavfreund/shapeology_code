# %%
import psutil

# %%
for proc in psutil.process_iter():
    try:
        pinfo = proc.as_dict(attrs=['pid', 'name', 'username'])
    except psutil.NoSuchProcess:
        pass
    else:
        if 'python' in pinfo['name']:
            print(pinfo)
# Out:
# {'name': 'python3.6', 'pid': 31772, 'username': 'yoavfreund'}
# {'name': 'python3.6', 'pid': 61039, 'username': 'yoavfreund'}
# {'name': 'python3.6', 'pid': 66583, 'username': 'yoavfreund'}
# {'name': 'python3.6', 'pid': 66600, 'username': 'yoavfreund'}

# %%
a=psutil.cpu_percent(percpu=True)
a, sum(a)
# Out:
# ([33.1, 1.7, 30.8, 2.1, 32.1, 1.7, 32.5, 1.9], 135.9)

# %%
# !ls ../../data/tifTiles/tiles_111*
# Out:
# ../../data/tifTiles/tiles_111.tif  ../../data/tifTiles/tiles_1115.tif
# ../../data/tifTiles/tiles_1110.tif ../../data/tifTiles/tiles_1116.tif
# ../../data/tifTiles/tiles_1111.tif ../../data/tifTiles/tiles_1117.tif
# ../../data/tifTiles/tiles_1112.tif ../../data/tifTiles/tiles_1118.tif
# ../../data/tifTiles/tiles_1113.tif ../../data/tifTiles/tiles_1119.tif
# ../../data/tifTiles/tiles_1114.tif

# %%
from os import getpid,system
from os.path import isfile
from glob import glob

# %%
def getLock(lockfile):
    try:
        l=open(lockfile, 'x')
        l.write(str(getpid()))
        l.close()
        return True
    except FileExistsError:
        return False

# %%
from time import sleep
from os.path import isfile

# %%
max_load=750.
job_no=200; i=0
for infile in glob('../../data/tifTiles/tiles_*.tif'):
    stem=infile[:-4]
    lockfile=stem+'.lock'
    if not isfile(lockfile):
        i+=1
        print('got lock',lockfile)
        command='python3 run_job.py %s &'%stem
        print(i,command)
        system(command)
        sleep(0.1)
    else:
        print('\r',lockfile,'exists',end='')

    if i>= job_no:
        break

    # Wait if load is too high
    load=sum(psutil.cpu_percent(percpu=True))
    print(i,'\r                            load:',load,end='')
    while load>max_load:
        print('\r',i,'load:',load,'    Sleeping',end='')
        sleep(2)
        load=sum(psutil.cpu_percent(percpu=True))
# Out:
#  ../../data/tifTiles/tiles_610.lock
#                             load: 0.0got lock ../../data/tifTiles/tiles_174.lock
# 1 python3 run_job.py ../../data/tifTiles/tiles_174 &
#                             load: 379.09999999999997got lock ../../data/tifTiles/tiles_612.lock
# 2 python3 run_job.py ../../data/tifTiles/tiles_612 &
#                             load: 402.79999999999995got lock ../../data/tifTiles/tiles_148.lock
# 3 python3 run_job.py ../../data/tifTiles/tiles_148 &
#                             load: 551.8got lock ../../data/tifTiles/tiles_389.lock
# 4 python3 run_job.py ../../data/tifTiles/tiles_389 &
#                             load: 647.8got lock ../../data/tifTiles/tiles_362.lock
# 5 python3 run_job.py ../../data/tifTiles/tiles_362 &
#  5 load: 772.7     Sleeping load: 772.7got lock ../../data/tifTiles/tiles_1074.lock
# 6 python3 run_job.py ../../data/tifTiles/tiles_1074 &
#                             load: 382.59999999999997got lock ../../data/tifTiles/tiles_404.lock
# 7 python3 run_job.py ../../data/tifTiles/tiles_404 &
#                             load: 0.0got lock ../../data/tifTiles/tiles_376.lock
# 8 python3 run_job.py ../../data/tifTiles/tiles_376 &
#                             load: 704.4999999999999got lock ../../data/tifTiles/tiles_1060.lock
# 9 python3 run_job.py ../../data/tifTiles/tiles_1060 &
#  9 load: 753.5999999999999     Sleeping999999999999got lock ../../data/tifTiles/tiles_1048.lock
# 10 python3 run_job.py ../../data/tifTiles/tiles_1048 &
#                             load: 624.9got lock ../../data/tifTiles/tiles_438.lock
# 11 python3 run_job.py ../../data/tifTiles/tiles_438 &
#                             load: 614.1got lock ../../data/tifTiles/tiles_1100.lock
# 12 python3 run_job.py ../../data/tifTiles/tiles_1100 &
#  12 load: 766.0     Sleepingload: 766.0got lock ../../data/tifTiles/tiles_216.lock
# 13 python3 run_job.py ../../data/tifTiles/tiles_216 &
#                             load: 614.8got lock ../../data/tifTiles/tiles_570.lock
# 14 python3 run_job.py ../../data/tifTiles/tiles_570 &
#                             load: 638.8got lock ../../data/tifTiles/tiles_564.lock
# 15 python3 run_job.py ../../data/tifTiles/tiles_564 &
#  15 load: 755.3     Sleepingload: 755.3got lock ../../data/tifTiles/tiles_1114.lock
# 16 python3 run_job.py ../../data/tifTiles/tiles_1114 &
#  16 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_202.lock
# 17 python3 run_job.py ../../data/tifTiles/tiles_202 &
#  17 load: 756.0999999999999     Sleeping99999999999got lock ../../data/tifTiles/tiles_558.lock
# 18 python3 run_job.py ../../data/tifTiles/tiles_558 &
#  18 load: 790.9     Sleepingload: 790.9got lock ../../data/tifTiles/tiles_1128.lock
# 19 python3 run_job.py ../../data/tifTiles/tiles_1128 &
#  19 load: 788.5     Sleepingload: 791.7got lock ../../data/tifTiles/tiles_969.lock
# 20 python3 run_job.py ../../data/tifTiles/tiles_969 &
#  20 load: 783.4000000000001     Sleeping00000000001got lock ../../data/tifTiles/tiles_955.lock
# 21 python3 run_job.py ../../data/tifTiles/tiles_955 &
#  21 load: 796.5     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_799.lock
# 22 python3 run_job.py ../../data/tifTiles/tiles_799 &
#  22 load: 790.5     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_941.lock
# 23 python3 run_job.py ../../data/tifTiles/tiles_941 &
#  23 load: 773.0     Sleepingload: 758.8got lock ../../data/tifTiles/tiles_772.lock
# 24 python3 run_job.py ../../data/tifTiles/tiles_772 &
#                             load: 650.8000000000001got lock ../../data/tifTiles/tiles_766.lock
# 25 python3 run_job.py ../../data/tifTiles/tiles_766 &
#                             load: 742.6999999999999got lock ../../data/tifTiles/tiles_996.lock
# 26 python3 run_job.py ../../data/tifTiles/tiles_996 &
#  26 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_982.lock
# 27 python3 run_job.py ../../data/tifTiles/tiles_982 &
#                             load: 737.6999999999999got lock ../../data/tifTiles/tiles_983.lock
# 28 python3 run_job.py ../../data/tifTiles/tiles_983 &
#  28 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_997.lock
# 29 python3 run_job.py ../../data/tifTiles/tiles_997 &
#                             load: 428.20000000000005got lock ../../data/tifTiles/tiles_767.lock
# 30 python3 run_job.py ../../data/tifTiles/tiles_767 &
#                             load: 573.6got lock ../../data/tifTiles/tiles_773.lock
# 31 python3 run_job.py ../../data/tifTiles/tiles_773 &
#  31 load: 762.6999999999999     Sleeping99999999999got lock ../../data/tifTiles/tiles_940.lock
# 32 python3 run_job.py ../../data/tifTiles/tiles_940 &
#                             load: 714.8got lock ../../data/tifTiles/tiles_798.lock
# 33 python3 run_job.py ../../data/tifTiles/tiles_798 &
#                             load: 608.5got lock ../../data/tifTiles/tiles_954.lock
# 34 python3 run_job.py ../../data/tifTiles/tiles_954 &
#                             load: 658.1got lock ../../data/tifTiles/tiles_968.lock
# 35 python3 run_job.py ../../data/tifTiles/tiles_968 &
#                             load: 664.3000000000001got lock ../../data/tifTiles/tiles_559.lock
# 36 python3 run_job.py ../../data/tifTiles/tiles_559 &
#  36 load: 774.3     Sleepingload: 774.3got lock ../../data/tifTiles/tiles_1129.lock
# 37 python3 run_job.py ../../data/tifTiles/tiles_1129 &
#                             load: 650.6999999999999got lock ../../data/tifTiles/tiles_565.lock
# 38 python3 run_job.py ../../data/tifTiles/tiles_565 &
#                             load: 662.3got lock ../../data/tifTiles/tiles_203.lock
# 39 python3 run_job.py ../../data/tifTiles/tiles_203 &
#                             load: 683.7got lock ../../data/tifTiles/tiles_1115.lock
# 40 python3 run_job.py ../../data/tifTiles/tiles_1115 &
#  40 load: 770.9     Sleepingload: 770.9got lock ../../data/tifTiles/tiles_217.lock
# 41 python3 run_job.py ../../data/tifTiles/tiles_217 &
#                             load: 726.1999999999999got lock ../../data/tifTiles/tiles_1101.lock
# 42 python3 run_job.py ../../data/tifTiles/tiles_1101 &
#  42 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_571.lock
# 43 python3 run_job.py ../../data/tifTiles/tiles_571 &
#                             load: 676.3got lock ../../data/tifTiles/tiles_1049.lock
# 44 python3 run_job.py ../../data/tifTiles/tiles_1049 &
#                             load: 676.3000000000001got lock ../../data/tifTiles/tiles_439.lock
# 45 python3 run_job.py ../../data/tifTiles/tiles_439 &
#                             load: 0.0got lock ../../data/tifTiles/tiles_1061.lock
# 46 python3 run_job.py ../../data/tifTiles/tiles_1061 &
#                             load: 727.8got lock ../../data/tifTiles/tiles_377.lock
# 47 python3 run_job.py ../../data/tifTiles/tiles_377 &
#  47 load: 799.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_1075.lock
# 48 python3 run_job.py ../../data/tifTiles/tiles_1075 &
#                             load: 583.0999999999999got lock ../../data/tifTiles/tiles_363.lock
# 49 python3 run_job.py ../../data/tifTiles/tiles_363 &
#                             load: 547.2got lock ../../data/tifTiles/tiles_405.lock
# 50 python3 run_job.py ../../data/tifTiles/tiles_405 &
#                             load: 713.6got lock ../../data/tifTiles/tiles_388.lock
# 51 python3 run_job.py ../../data/tifTiles/tiles_388 &
#                             load: 699.8999999999999got lock ../../data/tifTiles/tiles_149.lock
# 52 python3 run_job.py ../../data/tifTiles/tiles_149 &
#  52 load: 797.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_175.lock
# 53 python3 run_job.py ../../data/tifTiles/tiles_175 &
#                             load: 605.5got lock ../../data/tifTiles/tiles_613.lock
# 54 python3 run_job.py ../../data/tifTiles/tiles_613 &
#                             load: 736.8got lock ../../data/tifTiles/tiles_607.lock
# 55 python3 run_job.py ../../data/tifTiles/tiles_607 &
#  55 load: 766.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_161.lock
# 56 python3 run_job.py ../../data/tifTiles/tiles_161 &
#  56 load: 760.5     Sleepingload: 791.7got lock ../../data/tifTiles/tiles_39.lock
# 57 python3 run_job.py ../../data/tifTiles/tiles_39 &
#  57 load: 798.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_834.lock
# 58 python3 run_job.py ../../data/tifTiles/tiles_834 &
#  58 load: 773.5     Sleepinggot lock ../../data/tifTiles/tiles_820.lock
# 59 python3 run_job.py ../../data/tifTiles/tiles_820 &
#                             load: 611.7got lock ../../data/tifTiles/tiles_05.lock
# 60 python3 run_job.py ../../data/tifTiles/tiles_05 &
#                             load: 716.1999999999999got lock ../../data/tifTiles/tiles_808.lock
# 61 python3 run_job.py ../../data/tifTiles/tiles_808 &
#  61 load: 790.5     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_11.lock
# 62 python3 run_job.py ../../data/tifTiles/tiles_11 &
#                             load: 523.1999999999999got lock ../../data/tifTiles/tiles_847.lock
# 63 python3 run_job.py ../../data/tifTiles/tiles_847 &
#                             load: 639.1got lock ../../data/tifTiles/tiles_853.lock
# 64 python3 run_job.py ../../data/tifTiles/tiles_853 &
#  64 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_76.lock
# 65 python3 run_job.py ../../data/tifTiles/tiles_76 &
#                             load: 710.4got lock ../../data/tifTiles/tiles_62.lock
# 66 python3 run_job.py ../../data/tifTiles/tiles_62 &
#                             load: 678.5got lock ../../data/tifTiles/tiles_884.lock
# 67 python3 run_job.py ../../data/tifTiles/tiles_884 &
#  67 load: 754.6999999999999     Sleeping99999999999got lock ../../data/tifTiles/tiles_89.lock
# 68 python3 run_job.py ../../data/tifTiles/tiles_89 &
#                             load: 515.1got lock ../../data/tifTiles/tiles_648.lock
# 69 python3 run_job.py ../../data/tifTiles/tiles_648 &
#                             load: 464.49999999999994got lock ../../data/tifTiles/tiles_890.lock
# 70 python3 run_job.py ../../data/tifTiles/tiles_890 &
#                             load: 717.8got lock ../../data/tifTiles/tiles_660.lock
# 71 python3 run_job.py ../../data/tifTiles/tiles_660 &
#  71 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_106.lock
# 72 python3 run_job.py ../../data/tifTiles/tiles_106 &
#                             load: 618.7got lock ../../data/tifTiles/tiles_112.lock
# 73 python3 run_job.py ../../data/tifTiles/tiles_112 &
#                             load: 716.3got lock ../../data/tifTiles/tiles_674.lock
# 74 python3 run_job.py ../../data/tifTiles/tiles_674 &
#  74 load: 800.0     Sleepingload: 800.0got lock ../../data/tifTiles/tiles_489.lock
# 75 python3 run_job.py ../../data/tifTiles/tiles_489 &
#  75 load: 753.6     Sleepingload: 753.6got lock ../../data/tifTiles/tiles_338.lock
# 76 python3 run_job.py ../../data/tifTiles/tiles_338 &
#                             load: 410.0got lock ../../data/tifTiles/tiles_304.lock
# 77 python3 run_job.py ../../data/tifTiles/tiles_304 &
#                             load: 538.5got lock ../../data/tifTiles/tiles_1012.lock
# 78 python3 run_job.py ../../data/tifTiles/tiles_1012 &
#                             load: 695.3got lock ../../data/tifTiles/tiles_462.lock
# 79 python3 run_job.py ../../data/tifTiles/tiles_462 &
#                             load: 727.9got lock ../../data/tifTiles/tiles_476.lock
# 80 python3 run_job.py ../../data/tifTiles/tiles_476 &
#  80 load: 799.5     Sleepingload: 800.0

# %%
# %%writefile run_job.py
from sys import argv
from os import getpid,system
from os.path import isfile
from time import sleep
import datetime


def getLock(lockfile):
    try:
        l=open(lockfile, 'x')
        return l
    except FileExistsError:
        return None

stem=argv[1]
lockfilename=stem+'.lock'
logfilename=stem+'.log'

lockfile=getLock(lockfilename)
if not lockfile is None:

    command='python3 ../scripts/extractPatches.py %s > %s'%(stem,logfilename)
    # put some info into the log/lock file
    now = datetime.datetime.now()
    print('pid=',getpid(), file=lockfile)
    print('start time=',now.isoformat(), file=lockfile)
    print('command=',command, file=lockfile)
    
    system(command)
    sleep(1)
else:
    print(lockfilename,'exists, skipping')
# Out:
# Overwriting run_job.py

# %%
# %pwd
# Out:
# '/Users/yoavfreund/projects/shapeology/shapeology_code/notebooks'

# %%
stem='/Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00'
# !rm {stem}.l*
# !ls {stem}*
# Out:
# /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.tif

# %%
# !python3 ../scripts/extractPatches.py /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00 > /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.log

# %%
# !python3 run_job.py $stem

# %%
# !cat {stem}.lo*
# Out:
# pid= 33233
# start time= 2018-09-08T10:10:40.730924
# command= python3 ../scripts/extractPatches.py /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00 > /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.log
# image /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.tif too blank, skipping

# %%
# !ls -l {stem}.*
# Out:
# -rw-r--r--  1 yoavfreund  staff      224 Sep  8 10:10 /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.lock
# -rw-r--r--  1 yoavfreund  staff       91 Sep  8 10:10 /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.log
# -rw-r--r--  1 yoavfreund  staff  6008316 Sep  6 20:49 /Users/yoavfreund/projects/shapeology/data/tifTiles/tiles_00.tif

# %%
import datetime

now = datetime.datetime.now()
print(now.isoformat())
print(now.strftime("%Y-%m-%d %H:%M"))
# Out:
# 2018-09-08T09:27:21.653231
# 2018-09-08 09:27

# %%
# !cat ../../data/tifTiles/tiles_*.log
# Out:
# image ../../data/tifTiles/tiles_00.tif too blank, skipping
# image ../../data/tifTiles/tiles_01.tif too blank, skipping
# image ../../data/tifTiles/tiles_02.tif too blank, skipping
# image ../../data/tifTiles/tiles_03.tif too blank, skipping
# image ../../data/tifTiles/tiles_07.tif too blank, skipping
# image ../../data/tifTiles/tiles_1058.tif too blank, skipping
# image ../../data/tifTiles/tiles_1059.tif too blank, skipping
# image ../../data/tifTiles/tiles_1063.tif too blank, skipping
# image ../../data/tifTiles/tiles_1064.tif too blank, skipping
# image ../../data/tifTiles/tiles_1065.tif too blank, skipping
# processing ../../data/tifTiles/tiles_1066.tif into ../../data/tifTiles/tiles_1066_extracted.pkl
# found 143 patches
# finished in  32.1 seconds
# image ../../data/tifTiles/tiles_1067.tif too blank, skipping
# image ../../data/tifTiles/tiles_1070.tif too blank, skipping
# image ../../data/tifTiles/tiles_1071.tif too blank, skipping
# image ../../data/tifTiles/tiles_1072.tif too blank, skipping
# image ../../data/tifTiles/tiles_1073.tif too blank, skipping
# image ../../data/tifTiles/tiles_1077.tif too blank, skipping
# image ../../data/tifTiles/tiles_1088.tif too blank, skipping
# image ../../data/tifTiles/tiles_1098.tif too blank, skipping
# image ../../data/tifTiles/tiles_1099.tif too blank, skipping
# image ../../data/tifTiles/tiles_1103.tif too blank, skipping
# image ../../data/tifTiles/tiles_1104.tif too blank, skipping
# image ../../data/tifTiles/tiles_1105.tif too blank, skipping
# image ../../data/tifTiles/tiles_1106.tif too blank, skipping
# image ../../data/tifTiles/tiles_1107.tif too blank, skipping
# image ../../data/tifTiles/tiles_1110.tif too blank, skipping
# image ../../data/tifTiles/tiles_1111.tif too blank, skipping
# image ../../data/tifTiles/tiles_1112.tif too blank, skipping
# image ../../data/tifTiles/tiles_1113.tif too blank, skipping
# image ../../data/tifTiles/tiles_1117.tif too blank, skipping
# image ../../data/tifTiles/tiles_1138.tif too blank, skipping
# image ../../data/tifTiles/tiles_1139.tif too blank, skipping
# image ../../data/tifTiles/tiles_13.tif too blank, skipping
# image ../../data/tifTiles/tiles_14.tif too blank, skipping
# image ../../data/tifTiles/tiles_15.tif too blank, skipping
# image ../../data/tifTiles/tiles_158.tif too blank, skipping
# image ../../data/tifTiles/tiles_159.tif too blank, skipping
# image ../../data/tifTiles/tiles_16.tif too blank, skipping
# image ../../data/tifTiles/tiles_163.tif too blank, skipping
# image ../../data/tifTiles/tiles_164.tif too blank, skipping
# image ../../data/tifTiles/tiles_165.tif too blank, skipping
# image ../../data/tifTiles/tiles_166.tif too blank, skipping
# image ../../data/tifTiles/tiles_167.tif too blank, skipping
# image ../../data/tifTiles/tiles_17.tif too blank, skipping
# image ../../data/tifTiles/tiles_170.tif too blank, skipping
# image ../../data/tifTiles/tiles_171.tif too blank, skipping
# image ../../data/tifTiles/tiles_172.tif too blank, skipping
# image ../../data/tifTiles/tiles_173.tif too blank, skipping
# image ../../data/tifTiles/tiles_177.tif too blank, skipping
# image ../../data/tifTiles/tiles_188.tif too blank, skipping
# image ../../data/tifTiles/tiles_198.tif too blank, skipping
# image ../../data/tifTiles/tiles_199.tif too blank, skipping
# image ../../data/tifTiles/tiles_201.tif too blank, skipping
# image ../../data/tifTiles/tiles_204.tif too blank, skipping
# image ../../data/tifTiles/tiles_205.tif too blank, skipping
# image ../../data/tifTiles/tiles_206.tif too blank, skipping
# image ../../data/tifTiles/tiles_207.tif too blank, skipping
# image ../../data/tifTiles/tiles_210.tif too blank, skipping
# image ../../data/tifTiles/tiles_211.tif too blank, skipping
# image ../../data/tifTiles/tiles_212.tif too blank, skipping
# image ../../data/tifTiles/tiles_213.tif too blank, skipping
# processing ../../data/tifTiles/tiles_215.tif into ../../data/tifTiles/tiles_215_extracted.pkl
# found 131 patches
# finished in  17.3 seconds
# image ../../data/tifTiles/tiles_229.tif too blank, skipping
# image ../../data/tifTiles/tiles_238.tif too blank, skipping
# image ../../data/tifTiles/tiles_239.tif too blank, skipping
# image ../../data/tifTiles/tiles_280.tif too blank, skipping
# image ../../data/tifTiles/tiles_281.tif too blank, skipping
# image ../../data/tifTiles/tiles_282.tif too blank, skipping
# image ../../data/tifTiles/tiles_283.tif too blank, skipping
# image ../../data/tifTiles/tiles_284.tif too blank, skipping
# image ../../data/tifTiles/tiles_285.tif too blank, skipping
# image ../../data/tifTiles/tiles_286.tif too blank, skipping
# image ../../data/tifTiles/tiles_287.tif too blank, skipping
# image ../../data/tifTiles/tiles_288.tif too blank, skipping
# image ../../data/tifTiles/tiles_29.tif too blank, skipping
# image ../../data/tifTiles/tiles_349.tif too blank, skipping
# processing ../../data/tifTiles/tiles_358.tif into ../../data/tifTiles/tiles_358_extracted.pkl
# found 287 patches
# finished in  32.5 seconds
# processing ../../data/tifTiles/tiles_359.tif into ../../data/tifTiles/tiles_359_extracted.pkl
# found 225 patches
# finished in  27.5 seconds
# processing ../../data/tifTiles/tiles_361.tif into ../../data/tifTiles/tiles_361_extracted.pkl
# found 242 patches
# finished in  27.5 seconds
# processing ../../data/tifTiles/tiles_364.tif into ../../data/tifTiles/tiles_364_extracted.pkl
# found 304 patches
# finished in  32.1 seconds
# processing ../../data/tifTiles/tiles_365.tif into ../../data/tifTiles/tiles_365_extracted.pkl
# found 278 patches
# finished in  29.3 seconds
# processing ../../data/tifTiles/tiles_366.tif into ../../data/tifTiles/tiles_366_extracted.pkl
# found 334 patches
# finished in  26.6 seconds
# processing ../../data/tifTiles/tiles_367.tif into ../../data/tifTiles/tiles_367_extracted.pkl
# found 345 patches
# finished in  41.5 seconds
# processing ../../data/tifTiles/tiles_370.tif into ../../data/tifTiles/tiles_370_extracted.pkl
# found 315 patches
# finished in  32.5 seconds
# processing ../../data/tifTiles/tiles_371.tif into ../../data/tifTiles/tiles_371_extracted.pkl
# found 210 patches
# finished in  28.1 seconds
# image ../../data/tifTiles/tiles_372.tif too blank, skipping
# image ../../data/tifTiles/tiles_373.tif too blank, skipping
# image ../../data/tifTiles/tiles_375.tif too blank, skipping
# processing ../../data/tifTiles/tiles_398.tif into ../../data/tifTiles/tiles_398_extracted.pkl
# found 147 patches
# finished in  36.8 seconds
# processing ../../data/tifTiles/tiles_399.tif into ../../data/tifTiles/tiles_399_extracted.pkl
# found 195 patches
# finished in  28.4 seconds
# processing ../../data/tifTiles/tiles_400.tif into ../../data/tifTiles/tiles_400_extracted.pkl
# found 300 patches
# finished in  25.3 seconds
# processing ../../data/tifTiles/tiles_401.tif into ../../data/tifTiles/tiles_401_extracted.pkl
# found 277 patches
# finished in  40.8 seconds
# processing ../../data/tifTiles/tiles_402.tif into ../../data/tifTiles/tiles_402_extracted.pkl
# found 270 patches
# finished in  29.8 seconds
# processing ../../data/tifTiles/tiles_403.tif into ../../data/tifTiles/tiles_403_extracted.pkl
# found 314 patches
# finished in  29.0 seconds
# processing ../../data/tifTiles/tiles_407.tif into ../../data/tifTiles/tiles_407_extracted.pkl
# found 256 patches
# finished in  27.8 seconds
# image ../../data/tifTiles/tiles_41.tif too blank, skipping
# processing ../../data/tifTiles/tiles_410.tif into ../../data/tifTiles/tiles_410_extracted.pkl
# found 256 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_411.tif into ../../data/tifTiles/tiles_411_extracted.pkl
# found 310 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_412.tif into ../../data/tifTiles/tiles_412_extracted.pkl
# found 300 patches
# finished in  47.8 seconds
# processing ../../data/tifTiles/tiles_413.tif into ../../data/tifTiles/tiles_413_extracted.pkl
# found 287 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_414.tif into ../../data/tifTiles/tiles_414_extracted.pkl
# found 348 patches
# finished in  48.0 seconds
# processing ../../data/tifTiles/tiles_415.tif into ../../data/tifTiles/tiles_415_extracted.pkl
# found 305 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_416.tif into ../../data/tifTiles/tiles_416_extracted.pkl
# found 300 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_417.tif into ../../data/tifTiles/tiles_417_extracted.pkl
# found 338 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_418.tif into ../../data/tifTiles/tiles_418_extracted.pkl
# found 343 patches
# finished in  47.9 seconds
# processing ../../data/tifTiles/tiles_419.tif into ../../data/tifTiles/tiles_419_extracted.pkl
# found 338 patches
# finished in  47.8 seconds
# image ../../data/tifTiles/tiles_428.tif too blank, skipping
# image ../../data/tifTiles/tiles_429.tif too blank, skipping
# processing ../../data/tifTiles/tiles_548.tif into ../../data/tifTiles/tiles_548_extracted.pkl
# found 311 patches
# finished in  23.6 seconds
# processing ../../data/tifTiles/tiles_549.tif into ../../data/tifTiles/tiles_549_extracted.pkl
# found 276 patches
# finished in  41.8 seconds
# processing ../../data/tifTiles/tiles_560.tif into ../../data/tifTiles/tiles_560_extracted.pkl
# found 277 patches
# finished in  26.0 seconds
# processing ../../data/tifTiles/tiles_561.tif into ../../data/tifTiles/tiles_561_extracted.pkl
# found 277 patches
# finished in  39.3 seconds
# processing ../../data/tifTiles/tiles_562.tif into ../../data/tifTiles/tiles_562_extracted.pkl
# found 296 patches
# finished in  22.0 seconds
# processing ../../data/tifTiles/tiles_563.tif into ../../data/tifTiles/tiles_563_extracted.pkl
# found 290 patches
# finished in  28.4 seconds
# image ../../data/tifTiles/tiles_567.tif too blank, skipping
# image ../../data/tifTiles/tiles_573.tif too blank, skipping
# image ../../data/tifTiles/tiles_574.tif too blank, skipping
# image ../../data/tifTiles/tiles_575.tif too blank, skipping
# image ../../data/tifTiles/tiles_576.tif too blank, skipping
# image ../../data/tifTiles/tiles_577.tif too blank, skipping
# image ../../data/tifTiles/tiles_588.tif too blank, skipping
# image ../../data/tifTiles/tiles_589.tif too blank, skipping
# processing ../../data/tifTiles/tiles_598.tif into ../../data/tifTiles/tiles_598_extracted.pkl
# found 273 patches
# finished in  24.4 seconds
# processing ../../data/tifTiles/tiles_600.tif into ../../data/tifTiles/tiles_600_extracted.pkl
# found 305 patches
# finished in  31.1 seconds
# processing ../../data/tifTiles/tiles_601.tif into ../../data/tifTiles/tiles_601_extracted.pkl
# found 327 patches
# finished in  26.5 seconds
# processing ../../data/tifTiles/tiles_602.tif into ../../data/tifTiles/tiles_602_extracted.pkl
# found 275 patches
# finished in  29.5 seconds
# processing ../../data/tifTiles/tiles_603.tif into ../../data/tifTiles/tiles_603_extracted.pkl
# found 280 patches
# finished in  32.8 seconds
# processing ../../data/tifTiles/tiles_605.tif into ../../data/tifTiles/tiles_605_extracted.pkl
# found 282 patches
# finished in  27.8 seconds
# processing ../../data/tifTiles/tiles_611.tif into ../../data/tifTiles/tiles_611_extracted.pkl
# found 263 patches
# finished in  26.1 seconds
# processing ../../data/tifTiles/tiles_614.tif into ../../data/tifTiles/tiles_614_extracted.pkl
# found 246 patches
# finished in  15.4 seconds
# processing ../../data/tifTiles/tiles_615.tif into ../../data/tifTiles/tiles_615_extracted.pkl
# found 146 patches
# finished in  15.1 seconds
# image ../../data/tifTiles/tiles_616.tif too blank, skipping
# image ../../data/tifTiles/tiles_617.tif too blank, skipping
# image ../../data/tifTiles/tiles_628.tif too blank, skipping
# image ../../data/tifTiles/tiles_629.tif too blank, skipping
# processing ../../data/tifTiles/tiles_639.tif into ../../data/tifTiles/tiles_639_extracted.pkl
# found 177 patches
# finished in  28.2 seconds
# processing ../../data/tifTiles/tiles_748.tif into ../../data/tifTiles/tiles_748_extracted.pkl
# found 146 patches
# finished in  20.9 seconds
# processing ../../data/tifTiles/tiles_749.tif into ../../data/tifTiles/tiles_749_extracted.pkl
# found 172 patches
# finished in  24.3 seconds
# image ../../data/tifTiles/tiles_758.tif too blank, skipping
# image ../../data/tifTiles/tiles_759.tif too blank, skipping
# image ../../data/tifTiles/tiles_760.tif too blank, skipping
# image ../../data/tifTiles/tiles_761.tif too blank, skipping
# image ../../data/tifTiles/tiles_762.tif too blank, skipping
# image ../../data/tifTiles/tiles_763.tif too blank, skipping
# image ../../data/tifTiles/tiles_765.tif too blank, skipping
# image ../../data/tifTiles/tiles_770.tif too blank, skipping
# image ../../data/tifTiles/tiles_771.tif too blank, skipping
# image ../../data/tifTiles/tiles_774.tif too blank, skipping
# image ../../data/tifTiles/tiles_775.tif too blank, skipping
# image ../../data/tifTiles/tiles_776.tif too blank, skipping
# image ../../data/tifTiles/tiles_777.tif too blank, skipping
# processing ../../data/tifTiles/tiles_788.tif into ../../data/tifTiles/tiles_788_extracted.pkl
# found 274 patches
# finished in  38.7 seconds
# processing ../../data/tifTiles/tiles_789.tif into ../../data/tifTiles/tiles_789_extracted.pkl
# found 283 patches
# finished in  28.3 seconds
# image ../../data/tifTiles/tiles_818.tif too blank, skipping
# image ../../data/tifTiles/tiles_819.tif too blank, skipping
# image ../../data/tifTiles/tiles_822.tif too blank, skipping
# image ../../data/tifTiles/tiles_824.tif too blank, skipping
# image ../../data/tifTiles/tiles_825.tif too blank, skipping
# image ../../data/tifTiles/tiles_826.tif too blank, skipping
# image ../../data/tifTiles/tiles_827.tif too blank, skipping
# image ../../data/tifTiles/tiles_830.tif too blank, skipping
# image ../../data/tifTiles/tiles_831.tif too blank, skipping
# image ../../data/tifTiles/tiles_832.tif too blank, skipping
# image ../../data/tifTiles/tiles_833.tif too blank, skipping
# processing ../../data/tifTiles/tiles_836.tif into ../../data/tifTiles/tiles_836_extracted.pkl
# found 162 patches
# finished in  23.3 seconds
# image ../../data/tifTiles/tiles_942.tif too blank, skipping
# image ../../data/tifTiles/tiles_944.tif too blank, skipping
# image ../../data/tifTiles/tiles_945.tif too blank, skipping
# image ../../data/tifTiles/tiles_946.tif too blank, skipping
# image ../../data/tifTiles/tiles_947.tif too blank, skipping
# image ../../data/tifTiles/tiles_950.tif too blank, skipping
# image ../../data/tifTiles/tiles_951.tif too blank, skipping
# image ../../data/tifTiles/tiles_952.tif too blank, skipping
# image ../../data/tifTiles/tiles_953.tif too blank, skipping
# image ../../data/tifTiles/tiles_956.tif too blank, skipping
# image ../../data/tifTiles/tiles_978.tif too blank, skipping
# image ../../data/tifTiles/tiles_979.tif too blank, skipping
# image ../../data/tifTiles/tiles_980.tif too blank, skipping
# image ../../data/tifTiles/tiles_981.tif too blank, skipping
# image ../../data/tifTiles/tiles_984.tif too blank, skipping
# image ../../data/tifTiles/tiles_985.tif too blank, skipping
# image ../../data/tifTiles/tiles_986.tif too blank, skipping
# image ../../data/tifTiles/tiles_987.tif too blank, skipping
# image ../../data/tifTiles/tiles_990.tif too blank, skipping
# image ../../data/tifTiles/tiles_991.tif too blank, skipping
# image ../../data/tifTiles/tiles_992.tif too blank, skipping
# image ../../data/tifTiles/tiles_993.tif too blank, skipping
# image ../../data/tifTiles/tiles_994.tif too blank, skipping
# image ../../data/tifTiles/tiles_995.tif too blank, skipping

# %%
# !rm ../../data/tifTiles/tiles_*.lock

# %%
# !rm ../../data/tifTiles/tiles_29.lock

# %%
# !cat ../../data/tifTiles/tiles_29.lock
# Out:
# 72484
