# %%
import pickle as pk
import numpy as np
from glob import glob
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
stack='MD589'
cell_dir = os.environ['ROOT_DIR']+'CSHL_cells_dm/'+stack+'/'

# %%
structures = [dir for dir in glob(cell_dir+'/*')]
print(structures)
# Out:
# ['/Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/5N', '/Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/6N']

# %%
samples = [dir for dir in glob(structures[1]+'/*')]
print(samples)
# Out:
# ['/Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/6N/MD589_6N_negative.pkl', '/Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/6N/MD589_6N_positive.pkl']

# %%
sample=pk.load(open(samples[0],'rb'))

# %%
dm=[]
for i in range(len(sample)):
    if sample[i]['padded_size']==15:
        dm.append(sample[i]['DMVec'])

# %%
dm=np.array(dm)
dm.shape
# Out:
# (6535, 200)

# %%
pylab.scatter(dm[:,0],dm[:,1])
figure()
pylab.scatter(dm[:,0],dm[:,2])

# %%
# !aws s3 cp s3://mousebraindata-open/MD657/DiffusionMaps/diffusionMap.pkl diffusionMap_test.pkl
# Out:
# download: s3://mousebraindata-open/MD657/DiffusionMaps/diffusionMap.pkl to ./diffusionMap_test.pkl

# %%
dm=pk.load(open('diffusionMap_test.pkl','rb'))
