# %%
s3dir='s3://mousebraindata-open/MD657/permuted/'
L=!aws s3 ls $s3dir
L
# Out:
# ['2018-12-28 01:33:02  351893561 permuted-15.tgz',
#  '2018-12-28 01:57:46 2337888441 permuted-151.tgz',
#  '2018-12-28 02:00:24  407649744 permuted-201.tgz',
#  '2018-12-28 01:39:05 1639192882 permuted-27.tgz',
#  '2018-12-28 01:26:24 4656683236 permuted-51.tgz',
#  '2018-12-28 01:49:26 3960502846 permuted-81.tgz']

# %%
for line in L:
    parts=line.split()
    filename=parts[-1]
    if not 'lossless_patches' in filename:
        continue
    path=s3dir+filename
    #print(path)
    # !aws s3 rm $path
# Out:
# delete: s3://mousebraindata-open/MD657/MD657-F1-2017.02.17-17.39.26_MD657_1_0001_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F1-2017.02.17-17.39.26_MD657_2_0002_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F1-2017.02.17-17.39.26_MD657_3_0003_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F10-2017.02.17-19.35.42_MD657_1_0028_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F10-2017.02.17-19.35.42_MD657_3_0030_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F10-2017.02.21-17.57.42_MD657_1_0028_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F10-2017.02.21-17.57.42_MD657_2_0029_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F10-2017.02.21-17.57.42_MD657_3_0030_lossless_patches.tgz
# delete: s3://mousebraindata-open/MD657/MD657-F11-2017.02.17-19.39.47_MD657_1_0031_lossless_patches.tgz
# ...
