# %%
# !tail /home/ubuntu/watchdog.log
# Out:
# /home/ubuntu/shapeology_code/scripts/Controller-1545527461.log gap is    0.1
# Sun Dec 23 02:32:01 UTC 2018
# /home/ubuntu/KDU7A2_Demo_Apps_for_Centos7-x86-64_170827/
# /home/ubuntu/shapeology_code/scripts/Controller-1545527461.log gap is    3.9
# Sun Dec 23 02:33:01 UTC 2018
# /home/ubuntu/KDU7A2_Demo_Apps_for_Centos7-x86-64_170827/
# /home/ubuntu/shapeology_code/scripts/Controller-1545527461.log gap is    2.3
# Sun Dec 23 02:34:01 UTC 2018
# /home/ubuntu/KDU7A2_Demo_Apps_for_Centos7-x86-64_170827/
# /home/ubuntu/shapeology_code/scripts/Controller-1545527461.log gap is    4.1

# %%
# !tail -40 /home/ubuntu/shapeology_code/scripts/Controller-1545527461.log
# Out:
# got lock /dev/shm/data/tiles/tiles_02.lock 229
# cmd= python3 /home/ubuntu/shapeology_code/scripts/run_job.py /dev/shm/data/tiles/tiles_02 &
#    229                            load:   4.22
#
# load low enough 4.216666666666666
# got lock /dev/shm/data/tiles/tiles_01.lock 230
# cmd= python3 /home/ubuntu/shapeology_code/scripts/run_job.py /dev/shm/data/tiles/tiles_01 &
#    230                            load:  16.88
#
# load low enough 16.875
# got lock /dev/shm/data/tiles/tiles_00.lock 231
# cmd= python3 /home/ubuntu/shapeology_code/scripts/run_job.py /dev/shm/data/tiles/tiles_00 &
#    231                            load:  43.24
#
# load low enough 43.24166666666667
# 1545532476.9 	1 - processed    231 tiles
# tile_pattern= /dev/shm/data/tiles/tiles_*.tif
# 1545532476.9 	2 - processed      0 tiles
# ...

# %%
# !aws s3 ls s3://mousebraindata-open/MD657/ | grep MD657-F75-2017.02.18-16.21.28_MD657_1_0223
# Out:
# 2018-12-23 02:32:53         64 MD657-F75-2017.02.18-16.21.28_MD657_1_0223.lock-ip-172-31-21-46
# 2018-08-29 04:38:28    1516034 MD657-F75-2017.02.18-16.21.28_MD657_1_0223.png
# 2018-08-29 04:38:28    5702610 MD657-F75-2017.02.18-16.21.28_MD657_1_0223.tif
# 2018-08-29 04:38:28 1890013348 MD657-F75-2017.02.18-16.21.28_MD657_1_0223_lossless.jp2
# 2018-12-23 02:34:38      13304 MD657-F75-2017.02.18-16.21.28_MD657_1_0223_lossless_patches.tgz
# 2018-08-29 04:38:29   45570331 MD657-F75-2017.02.18-16.21.28_MD657_1_0223_lossy.jp2
