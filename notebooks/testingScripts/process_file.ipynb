# %%
# %cd ../../scripts/
# Out:
# /Users/yoavfreund/projects/shapeology/shapeology_code/scripts

# %%
# !python process_file.py s3://mousebraindata-open/MD657 MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless ../../data
# Out:
# 1545435474.5 	starting to process s3://mousebraindata-open/MD657/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless
# cmd= rm -rf ../../data/*
# cmd= mkdir ../../data/tiles
# 1545435475.1 	cleaning local directory
# cmd= aws s3 cp s3://mousebraindata-open/MD657/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless.jp2 ../../data/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless.jp2
# download: s3://mousebraindata-open/MD657/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless.jp2 to ../../data/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless.jp2
# 1545435539.9 	copied from s3: MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless
# cmd= kdu_expand -i ../../data/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless.jp2 -o ../../data/MD657-N48-2017.02.22-16.41.55_MD657_2_0143_lossless.tif
#
# Consumed 168 tile-part(s) from a total of 1 tile(s).
# Consumed 1,576,495,636 codestream bytes (excluding any file format) = 11.495009
# bits/pel.
# ...
