# %%
import datajoint as dj
import numpy as np
import json
from subprocess import call
import yaml
import sys, os
import pandas as pd
import ray

sys.path.append('./lib')
from utilities import *
sys.path.append('../lib')
from utils import run

# %%
#credFiles= '/data/Github/VaultBrain/credFiles_aws.yaml'
credFiles= '/Users/kuiqian/Github/VaultBrain/credFiles.yaml'
dj.config['database.host'] = get_dj_creds(credFiles)['database.host']
dj.config['database.user'] = get_dj_creds(credFiles)['database.user']
dj.config['database.port'] = get_dj_creds(credFiles)['database.port']
dj.config['database.password'] = get_dj_creds(credFiles)['database.password']
dj.conn()
# Out:
# ./lib/utilities.py:14: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   credFiles = yaml.load(open( credential_file_pointers,'r'))
# Connecting kui@ucsd-demo-db.datajoint.io:3306
# DataJoint connection (connected) kui@ucsd-demo-db.datajoint.io:3306

# %%
schema = dj.schema('kui_diffusionmap')
schema.spawn_missing_classes()

# %%
stack = 'MD594'
#yaml_file = 'shape_params-aws.yaml'
yaml_file = 'shape_params.yaml'
scripts_dir = os.environ['REPO_DIR']

# %%
fname = os.path.join('CSHL_data_processed', stack, 'Annotation.npy')
annotation = np.load(os.environ['ROOT_DIR']+fname, allow_pickle = True, encoding='latin1')
contours = pd.DataFrame(annotation)
contours = contours.rename(columns={0:"name", 1:"section", 2:"vertices"})
contours_grouped = contours.groupby('section')

# %%
sections = np.sort(contours['section'].unique())
sections
# Out:
# array([94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107,
#        108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
#        121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 132, 133, 134,
#        135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147,
#        148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160,
#        161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173,
#        174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186,
#        188, 189, 190, 191, 192, 194, 195, 196, 197, 198, 199, 200, 201,
#        202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214,
#        215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227,
#        228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 239, 240, 241,
#        242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254,
#        255, 256, 257, 258, 259, 260, 262, 263, 264, 265, 266, 267, 268,
#        269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281,
#        282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294,
#        295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307,
#        308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320,
#        321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333,
#        334, 335, 336, 337, 338, 339, 340, 342, 343, 344, 345, 346, 347,
#        348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360,
#        361, 362, 363, 364], dtype=object)

# %%
Section_v2.drop()
# Out:
# `kui_diffusionmap`.`section_v2` (265 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.  Restart kernel.

# %%
@schema
class SectionV2(dj.Manual):
    definition = """
    section_id  : int   # section number
    """

# %%
valid_sections = []
for section in sections:
    if contours_grouped.get_group(section).iterrows():
        valid_sections.append(section)

# %%
len(valid_sections), sections.shape
# Out:
# (265, (265,))

# %%
for section in valid_sections:
    print("\nAdding "+str(section)+' to the database')
    SectionV2.insert1(dict(section_id=section)
                      ,skip_duplicates=True)
# Out:
# Adding 94 to the database
#
# Adding 95 to the database
#
# Adding 96 to the database
#
# Adding 97 to the database
#
# Adding 98 to the database
#
# Adding 99 to the database
#
# Adding 100 to the database
#
# Adding 101 to the database
#
# Adding 102 to the database
#
# Adding 103 to the database
#
# Adding 104 to the database
#
# Adding 105 to the database
#
# Adding 106 to the database
#
# Adding 107 to the database
#
# Adding 108 to the database
#
# Adding 109 to the database
#
# Adding 110 to the database
#
# Adding 111 to the database
#
# Adding 112 to the database
#
# Adding 113 to the database
#
# Adding 114 to the database
#
# Adding 115 to the database
#
# Adding 116 to the database
#
# Adding 117 to the database
#
# Adding 118 to the database
#
# Adding 119 to the database
#
# Adding 120 to the database
#
# Adding 121 to the database
#
# Adding 122 to the database
#
# Adding 123 to the database
#
# Adding 124 to the database
#
# Adding 125 to the database
#
# Adding 126 to the database
#
# Adding 127 to the database
#
# Adding 128 to the database
#
# Adding 129 to the database
#
# Adding 130 to the database
#
# Adding 132 to the database
#
# Adding 133 to the database
#
# Adding 134 to the database
#
# Adding 135 to the database
#
# Adding 136 to the database
#
# Adding 137 to the database
#
# Adding 138 to the database
#
# Adding 139 to the database
#
# Adding 140 to the database
#
# Adding 141 to the database
#
# Adding 142 to the database
#
# Adding 143 to the database
#
# Adding 144 to the database
#
# Adding 145 to the database
#
# Adding 146 to the database
#
# Adding 147 to the database
#
# Adding 148 to the database
#
# Adding 149 to the database
#
# Adding 150 to the database
#
# Adding 151 to the database
#
# Adding 152 to the database
#
# Adding 153 to the database
#
# Adding 154 to the database
#
# Adding 155 to the database
#
# Adding 156 to the database
#
# Adding 157 to the database
#
# Adding 158 to the database
#
# Adding 159 to the database
#
# Adding 160 to the database
#
# Adding 161 to the database
#
# Adding 162 to the database
#
# Adding 163 to the database
#
# Adding 164 to the database
#
# Adding 165 to the database
#
# Adding 166 to the database
#
# Adding 167 to the database
#
# Adding 168 to the database
#
# Adding 169 to the database
#
# Adding 170 to the database
#
# Adding 171 to the database
#
# Adding 172 to the database
#
# Adding 173 to the database
#
# Adding 174 to the database
#
# Adding 175 to the database
#
# Adding 176 to the database
#
# Adding 177 to the database
#
# Adding 178 to the database
#
# Adding 179 to the database
#
# Adding 180 to the database
#
# Adding 181 to the database
#
# Adding 182 to the database
#
# Adding 183 to the database
#
# Adding 184 to the database
#
# Adding 185 to the database
#
# Adding 186 to the database
#
# Adding 188 to the database
#
# Adding 189 to the database
#
# Adding 190 to the database
#
# Adding 191 to the database
#
# Adding 192 to the database
#
# Adding 194 to the database
#
# Adding 195 to the database
#
# Adding 196 to the database
#
# Adding 197 to the database
#
# Adding 198 to the database
#
# Adding 199 to the database
#
# Adding 200 to the database
#
# Adding 201 to the database
#
# Adding 202 to the database
#
# Adding 203 to the database
#
# Adding 204 to the database
#
# Adding 205 to the database
#
# Adding 206 to the database
#
# Adding 207 to the database
#
# Adding 208 to the database
#
# Adding 209 to the database
#
# Adding 210 to the database
#
# Adding 211 to the database
#
# Adding 212 to the database
#
# Adding 213 to the database
#
# Adding 214 to the database
#
# Adding 215 to the database
#
# Adding 216 to the database
#
# Adding 217 to the database
#
# Adding 218 to the database
#
# Adding 219 to the database
#
# Adding 220 to the database
#
# Adding 221 to the database
#
# Adding 222 to the database
#
# Adding 223 to the database
#
# Adding 224 to the database
#
# Adding 225 to the database
#
# Adding 226 to the database
#
# Adding 227 to the database
#
# Adding 228 to the database
#
# Adding 229 to the database
#
# Adding 230 to the database
#
# Adding 231 to the database
#
# Adding 232 to the database
#
# Adding 233 to the database
#
# Adding 234 to the database
#
# Adding 235 to the database
#
# Adding 236 to the database
#
# Adding 237 to the database
#
# Adding 239 to the database
#
# Adding 240 to the database
#
# Adding 241 to the database
#
# Adding 242 to the database
#
# Adding 243 to the database
#
# Adding 244 to the database
#
# Adding 245 to the database
#
# Adding 246 to the database
#
# Adding 247 to the database
#
# Adding 248 to the database
#
# Adding 249 to the database
#
# Adding 250 to the database
#
# Adding 251 to the database
#
# Adding 252 to the database
#
# Adding 253 to the database
#
# Adding 254 to the database
#
# Adding 255 to the database
#
# Adding 256 to the database
#
# Adding 257 to the database
#
# Adding 258 to the database
#
# Adding 259 to the database
#
# Adding 260 to the database
#
# Adding 262 to the database
#
# Adding 263 to the database
#
# Adding 264 to the database
#
# Adding 265 to the database
#
# Adding 266 to the database
#
# Adding 267 to the database
#
# Adding 268 to the database
#
# Adding 269 to the database
#
# Adding 270 to the database
#
# Adding 271 to the database
#
# Adding 272 to the database
#
# Adding 273 to the database
#
# Adding 274 to the database
#
# Adding 275 to the database
#
# Adding 276 to the database
#
# Adding 277 to the database
#
# Adding 278 to the database
#
# Adding 279 to the database
#
# Adding 280 to the database
#
# Adding 281 to the database
#
# Adding 282 to the database
#
# Adding 283 to the database
#
# Adding 284 to the database
#
# Adding 285 to the database
#
# Adding 286 to the database
#
# Adding 287 to the database
#
# Adding 288 to the database
#
# Adding 289 to the database
#
# Adding 290 to the database
#
# Adding 291 to the database
#
# Adding 292 to the database
#
# Adding 293 to the database
#
# Adding 294 to the database
#
# Adding 295 to the database
#
# Adding 296 to the database
#
# Adding 297 to the database
#
# Adding 298 to the database
#
# Adding 299 to the database
#
# Adding 300 to the database
#
# Adding 301 to the database
#
# Adding 302 to the database
#
# Adding 303 to the database
#
# Adding 304 to the database
#
# Adding 305 to the database
#
# Adding 306 to the database
#
# Adding 307 to the database
#
# Adding 308 to the database
#
# Adding 309 to the database
#
# Adding 310 to the database
#
# Adding 311 to the database
#
# Adding 312 to the database
#
# Adding 313 to the database
#
# Adding 314 to the database
#
# Adding 315 to the database
#
# Adding 316 to the database
#
# Adding 317 to the database
#
# Adding 318 to the database
#
# Adding 319 to the database
#
# Adding 320 to the database
#
# Adding 321 to the database
#
# Adding 322 to the database
#
# Adding 323 to the database
#
# Adding 324 to the database
#
# Adding 325 to the database
#
# Adding 326 to the database
#
# Adding 327 to the database
#
# Adding 328 to the database
#
# Adding 329 to the database
#
# Adding 330 to the database
#
# Adding 331 to the database
#
# Adding 332 to the database
#
# Adding 333 to the database
#
# Adding 334 to the database
#
# Adding 335 to the database
#
# Adding 336 to the database
#
# Adding 337 to the database
#
# Adding 338 to the database
#
# Adding 339 to the database
#
# Adding 340 to the database
#
# Adding 342 to the database
#
# Adding 343 to the database
#
# Adding 344 to the database
#
# Adding 345 to the database
#
# Adding 346 to the database
#
# Adding 347 to the database
#
# Adding 348 to the database
#
# Adding 349 to the database
#
# Adding 350 to the database
#
# Adding 351 to the database
#
# Adding 352 to the database
#
# Adding 353 to the database
#
# Adding 354 to the database
#
# Adding 355 to the database
#
# Adding 356 to the database
#
# Adding 357 to the database
#
# Adding 358 to the database
#
# Adding 359 to the database
#
# Adding 360 to the database
#
# Adding 361 to the database
#
# Adding 362 to the database
#
# Adding 363 to the database
#
# Adding 364 to the database

# %%
SectionV2.fetch(as_dict=True)
# Out:
# [OrderedDict([('section_id', 94)]),
#  OrderedDict([('section_id', 95)]),
#  OrderedDict([('section_id', 96)]),
#  OrderedDict([('section_id', 97)]),
#  OrderedDict([('section_id', 98)]),
#  OrderedDict([('section_id', 99)]),
#  OrderedDict([('section_id', 100)]),
#  OrderedDict([('section_id', 101)]),
#  OrderedDict([('section_id', 102)]),
#  OrderedDict([('section_id', 103)]),
#  OrderedDict([('section_id', 104)]),
#  OrderedDict([('section_id', 105)]),
#  OrderedDict([('section_id', 106)]),
#  OrderedDict([('section_id', 107)]),
#  OrderedDict([('section_id', 108)]),
#  OrderedDict([('section_id', 109)]),
#  OrderedDict([('section_id', 110)]),
#  OrderedDict([('section_id', 111)]),
#  OrderedDict([('section_id', 112)]),
#  OrderedDict([('section_id', 113)]),
#  OrderedDict([('section_id', 114)]),
#  OrderedDict([('section_id', 115)]),
#  OrderedDict([('section_id', 116)]),
#  OrderedDict([('section_id', 117)]),
#  OrderedDict([('section_id', 118)]),
#  OrderedDict([('section_id', 119)]),
#  OrderedDict([('section_id', 120)]),
#  OrderedDict([('section_id', 121)]),
#  OrderedDict([('section_id', 122)]),
#  OrderedDict([('section_id', 123)]),
#  OrderedDict([('section_id', 124)]),
#  OrderedDict([('section_id', 125)]),
#  OrderedDict([('section_id', 126)]),
#  OrderedDict([('section_id', 127)]),
#  OrderedDict([('section_id', 128)]),
#  OrderedDict([('section_id', 129)]),
#  OrderedDict([('section_id', 130)]),
#  OrderedDict([('section_id', 132)]),
#  OrderedDict([('section_id', 133)]),
#  OrderedDict([('section_id', 134)]),
#  OrderedDict([('section_id', 135)]),
#  OrderedDict([('section_id', 136)]),
#  OrderedDict([('section_id', 137)]),
#  OrderedDict([('section_id', 138)]),
#  OrderedDict([('section_id', 139)]),
#  OrderedDict([('section_id', 140)]),
#  OrderedDict([('section_id', 141)]),
#  OrderedDict([('section_id', 142)]),
#  OrderedDict([('section_id', 143)]),
#  OrderedDict([('section_id', 144)]),
#  OrderedDict([('section_id', 145)]),
#  OrderedDict([('section_id', 146)]),
#  OrderedDict([('section_id', 147)]),
#  OrderedDict([('section_id', 148)]),
#  OrderedDict([('section_id', 149)]),
#  OrderedDict([('section_id', 150)]),
#  OrderedDict([('section_id', 151)]),
#  OrderedDict([('section_id', 152)]),
#  OrderedDict([('section_id', 153)]),
#  OrderedDict([('section_id', 154)]),
#  OrderedDict([('section_id', 155)]),
#  OrderedDict([('section_id', 156)]),
#  OrderedDict([('section_id', 157)]),
#  OrderedDict([('section_id', 158)]),
#  OrderedDict([('section_id', 159)]),
#  OrderedDict([('section_id', 160)]),
#  OrderedDict([('section_id', 161)]),
#  OrderedDict([('section_id', 162)]),
#  OrderedDict([('section_id', 163)]),
#  OrderedDict([('section_id', 164)]),
#  OrderedDict([('section_id', 165)]),
#  OrderedDict([('section_id', 166)]),
#  OrderedDict([('section_id', 167)]),
#  OrderedDict([('section_id', 168)]),
#  OrderedDict([('section_id', 169)]),
#  OrderedDict([('section_id', 170)]),
#  OrderedDict([('section_id', 171)]),
#  OrderedDict([('section_id', 172)]),
#  OrderedDict([('section_id', 173)]),
#  OrderedDict([('section_id', 174)]),
#  OrderedDict([('section_id', 175)]),
#  OrderedDict([('section_id', 176)]),
#  OrderedDict([('section_id', 177)]),
#  OrderedDict([('section_id', 178)]),
#  OrderedDict([('section_id', 179)]),
#  OrderedDict([('section_id', 180)]),
#  OrderedDict([('section_id', 181)]),
#  OrderedDict([('section_id', 182)]),
#  OrderedDict([('section_id', 183)]),
#  OrderedDict([('section_id', 184)]),
#  OrderedDict([('section_id', 185)]),
#  OrderedDict([('section_id', 186)]),
#  OrderedDict([('section_id', 188)]),
#  OrderedDict([('section_id', 189)]),
#  OrderedDict([('section_id', 190)]),
#  OrderedDict([('section_id', 191)]),
#  OrderedDict([('section_id', 192)]),
#  OrderedDict([('section_id', 194)]),
#  OrderedDict([('section_id', 195)]),
#  OrderedDict([('section_id', 196)]),
#  OrderedDict([('section_id', 197)]),
#  OrderedDict([('section_id', 198)]),
#  OrderedDict([('section_id', 199)]),
#  OrderedDict([('section_id', 200)]),
#  OrderedDict([('section_id', 201)]),
#  OrderedDict([('section_id', 202)]),
#  OrderedDict([('section_id', 203)]),
#  OrderedDict([('section_id', 204)]),
#  OrderedDict([('section_id', 205)]),
#  OrderedDict([('section_id', 206)]),
#  OrderedDict([('section_id', 207)]),
#  OrderedDict([('section_id', 208)]),
#  OrderedDict([('section_id', 209)]),
#  OrderedDict([('section_id', 210)]),
#  OrderedDict([('section_id', 211)]),
#  OrderedDict([('section_id', 212)]),
#  OrderedDict([('section_id', 213)]),
#  OrderedDict([('section_id', 214)]),
#  OrderedDict([('section_id', 215)]),
#  OrderedDict([('section_id', 216)]),
#  OrderedDict([('section_id', 217)]),
#  OrderedDict([('section_id', 218)]),
#  OrderedDict([('section_id', 219)]),
#  OrderedDict([('section_id', 220)]),
#  OrderedDict([('section_id', 221)]),
#  OrderedDict([('section_id', 222)]),
#  OrderedDict([('section_id', 223)]),
#  OrderedDict([('section_id', 224)]),
#  OrderedDict([('section_id', 225)]),
#  OrderedDict([('section_id', 226)]),
#  OrderedDict([('section_id', 227)]),
#  OrderedDict([('section_id', 228)]),
#  OrderedDict([('section_id', 229)]),
#  OrderedDict([('section_id', 230)]),
#  OrderedDict([('section_id', 231)]),
#  OrderedDict([('section_id', 232)]),
#  OrderedDict([('section_id', 233)]),
#  OrderedDict([('section_id', 234)]),
#  OrderedDict([('section_id', 235)]),
#  OrderedDict([('section_id', 236)]),
#  OrderedDict([('section_id', 237)]),
#  OrderedDict([('section_id', 239)]),
#  OrderedDict([('section_id', 240)]),
#  OrderedDict([('section_id', 241)]),
#  OrderedDict([('section_id', 242)]),
#  OrderedDict([('section_id', 243)]),
#  OrderedDict([('section_id', 244)]),
#  OrderedDict([('section_id', 245)]),
#  OrderedDict([('section_id', 246)]),
#  OrderedDict([('section_id', 247)]),
#  OrderedDict([('section_id', 248)]),
#  OrderedDict([('section_id', 249)]),
#  OrderedDict([('section_id', 250)]),
#  OrderedDict([('section_id', 251)]),
#  OrderedDict([('section_id', 252)]),
#  OrderedDict([('section_id', 253)]),
#  OrderedDict([('section_id', 254)]),
#  OrderedDict([('section_id', 255)]),
#  OrderedDict([('section_id', 256)]),
#  OrderedDict([('section_id', 257)]),
#  OrderedDict([('section_id', 258)]),
#  OrderedDict([('section_id', 259)]),
#  OrderedDict([('section_id', 260)]),
#  OrderedDict([('section_id', 262)]),
#  OrderedDict([('section_id', 263)]),
#  OrderedDict([('section_id', 264)]),
#  OrderedDict([('section_id', 265)]),
#  OrderedDict([('section_id', 266)]),
#  OrderedDict([('section_id', 267)]),
#  OrderedDict([('section_id', 268)]),
#  OrderedDict([('section_id', 269)]),
#  OrderedDict([('section_id', 270)]),
#  OrderedDict([('section_id', 271)]),
#  OrderedDict([('section_id', 272)]),
#  OrderedDict([('section_id', 273)]),
#  OrderedDict([('section_id', 274)]),
#  OrderedDict([('section_id', 275)]),
#  OrderedDict([('section_id', 276)]),
#  OrderedDict([('section_id', 277)]),
#  OrderedDict([('section_id', 278)]),
#  OrderedDict([('section_id', 279)]),
#  OrderedDict([('section_id', 280)]),
#  OrderedDict([('section_id', 281)]),
#  OrderedDict([('section_id', 282)]),
#  OrderedDict([('section_id', 283)]),
#  OrderedDict([('section_id', 284)]),
#  OrderedDict([('section_id', 285)]),
#  OrderedDict([('section_id', 286)]),
#  OrderedDict([('section_id', 287)]),
#  OrderedDict([('section_id', 288)]),
#  OrderedDict([('section_id', 289)]),
#  OrderedDict([('section_id', 290)]),
#  OrderedDict([('section_id', 291)]),
#  OrderedDict([('section_id', 292)]),
#  OrderedDict([('section_id', 293)]),
#  OrderedDict([('section_id', 294)]),
#  OrderedDict([('section_id', 295)]),
#  OrderedDict([('section_id', 296)]),
#  OrderedDict([('section_id', 297)]),
#  OrderedDict([('section_id', 298)]),
#  OrderedDict([('section_id', 299)]),
#  OrderedDict([('section_id', 300)]),
#  OrderedDict([('section_id', 301)]),
#  OrderedDict([('section_id', 302)]),
#  OrderedDict([('section_id', 303)]),
#  OrderedDict([('section_id', 304)]),
#  OrderedDict([('section_id', 305)]),
#  OrderedDict([('section_id', 306)]),
#  OrderedDict([('section_id', 307)]),
#  OrderedDict([('section_id', 308)]),
#  OrderedDict([('section_id', 309)]),
#  OrderedDict([('section_id', 310)]),
#  OrderedDict([('section_id', 311)]),
#  OrderedDict([('section_id', 312)]),
#  OrderedDict([('section_id', 313)]),
#  OrderedDict([('section_id', 314)]),
#  OrderedDict([('section_id', 315)]),
#  OrderedDict([('section_id', 316)]),
#  OrderedDict([('section_id', 317)]),
#  OrderedDict([('section_id', 318)]),
#  OrderedDict([('section_id', 319)]),
#  OrderedDict([('section_id', 320)]),
#  OrderedDict([('section_id', 321)]),
#  OrderedDict([('section_id', 322)]),
#  OrderedDict([('section_id', 323)]),
#  OrderedDict([('section_id', 324)]),
#  OrderedDict([('section_id', 325)]),
#  OrderedDict([('section_id', 326)]),
#  OrderedDict([('section_id', 327)]),
#  OrderedDict([('section_id', 328)]),
#  OrderedDict([('section_id', 329)]),
#  OrderedDict([('section_id', 330)]),
#  OrderedDict([('section_id', 331)]),
#  OrderedDict([('section_id', 332)]),
#  OrderedDict([('section_id', 333)]),
#  OrderedDict([('section_id', 334)]),
#  OrderedDict([('section_id', 335)]),
#  OrderedDict([('section_id', 336)]),
#  OrderedDict([('section_id', 337)]),
#  OrderedDict([('section_id', 338)]),
#  OrderedDict([('section_id', 339)]),
#  OrderedDict([('section_id', 340)]),
#  OrderedDict([('section_id', 342)]),
#  OrderedDict([('section_id', 343)]),
#  OrderedDict([('section_id', 344)]),
#  OrderedDict([('section_id', 345)]),
#  OrderedDict([('section_id', 346)]),
#  OrderedDict([('section_id', 347)]),
#  OrderedDict([('section_id', 348)]),
#  OrderedDict([('section_id', 349)]),
#  OrderedDict([('section_id', 350)]),
#  OrderedDict([('section_id', 351)]),
#  OrderedDict([('section_id', 352)]),
#  OrderedDict([('section_id', 353)]),
#  OrderedDict([('section_id', 354)]),
#  OrderedDict([('section_id', 355)]),
#  OrderedDict([('section_id', 356)]),
#  OrderedDict([('section_id', 357)]),
#  OrderedDict([('section_id', 358)]),
#  OrderedDict([('section_id', 359)]),
#  OrderedDict([('section_id', 360)]),
#  OrderedDict([('section_id', 361)]),
#  OrderedDict([('section_id', 362)]),
#  OrderedDict([('section_id', 363)]),
#  OrderedDict([('section_id', 364)])]

# %%
schema.jobs
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid      connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +------+ +------------+ +------------+
# __shift        0a09c8844ba8f0 error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.22. ip-172-31-22-3 8949     35579          2019-08-28 01:
# __shift        0f28b5d49b3020 error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.24. ip-172-31-24-5 8834     35576          2019-08-28 01:
# __shift        1385974ed5904a error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.16. ip-172-31-16-1 8840     35575          2019-08-28 01:
# __shift        1c9ac0159c94d8 reserved     =BLOB=                    =BLOB=     kui@172.31.24. ip-172-31-24-1 8828     35580          2019-08-28 01:
# __shift        1d7f7abc18fcb4 reserved     =BLOB=                    =BLOB=     kui@172.31.31. ip-172-31-31-6 8960     35577          2019-08-28 01:
# __shift        2a79ea27c279e4 reserved     =BLOB=                    =BLOB=     kui@172.31.18. ip-172-31-18-2 8914     35582          2019-08-28 01:
# __shift        2b24d495052a8c error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.24. ip-172-31-24-1 8828     35580          2019-08-28 01:
# __shift        37a749d808e464 reserved     =BLOB=                    =BLOB=     kui@172.31.17. ip-172-31-17-1 8946     35578          2019-08-28 01:
# __shift        47d1e990583c9c error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.25. ip-172-31-25-2 8909     35583          2019-08-28 01:
# __shift        6c4b761a28b734 reserved     =BLOB=                    =BLOB=     kui@172.31.24. ip-172-31-24-5 8834     35576          2019-08-28 01:
# __shift        7ef605fc8dba54 reserved     =BLOB=                    =BLOB=     kui@172.31.16. ip-172-31-16-1 8840     35575          2019-08-28 01:
# __shift        8d5e957f297893 error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.18. ip-172-31-18-2 8914     35582          2019-08-28 01:
#    ...
#  (Total: 19)

# %%
(schema.jobs & 'status="error"')
# Out:
# *table_name    *key_hash    status     key        error_message  error_stac user     host     pid     connection_id  timestamp
# +------------+ +----------+ +--------+ +--------+ +------------+ +--------+ +------+ +------+ +-----+ +------------+ +-----------+
#
#  (Total: 0)

# %%
(schema.jobs & 'status="reserved"' )
# Out:
# *table_name    *key_hash    status     key        error_message  error_stac user     host     pid     connection_id  timestamp
# +------------+ +----------+ +--------+ +--------+ +------------+ +--------+ +------+ +------+ +-----+ +------------+ +-----------+
#
#  (Total: 0)

# %%
(schema.jobs & 'host="Kuis-MacBook-Pro.local"' )
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid       connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-------+ +------------+ +------------+
# __shift        a8baa56554f963 reserved     =BLOB=                    =BLOB=     kui@76.176.26. Kuis-MacBook-P 16956     21533          2019-07-18 08:
#  (Total: 1)

# %%
(schema.jobs & 'host="ip-172-31-20-67"' )
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host           pid      connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +------------+ +------+ +------------+ +------------+
# __shift        1d7f7abc18fcb4 reserved     =BLOB=                    =BLOB=     kui@172.31.20. ip-172-31-20-6 8901     33116          2019-08-22 03:
# __shift        698d51a19d8a12 error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.20. ip-172-31-20-6 8901     33116          2019-08-22 02:
# __shift        e00da03b685a0d error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.20. ip-172-31-20-6 8901     33116          2019-08-22 03:
# __shift        ec5decca5ed3d6 error        =BLOB=     NoSuchKey: NoS =BLOB=     kui@172.31.20. ip-172-31-20-6 8901     33116          2019-08-22 02:
#  (Total: 4)

# %%
(schema.jobs & 'status="reserved"' ).delete()
(schema.jobs & 'status="error"' ).delete()

# %%
Shift.fetch(as_dict=True)
# Out:
# [OrderedDict([('section_id', 94), ('size_of_file', 5)]),
#  OrderedDict([('section_id', 95), ('size_of_file', 5)]),
#  OrderedDict([('section_id', 96), ('size_of_file', 5)]),
#  OrderedDict([('section_id', 97), ('size_of_file', 5)]),
#  OrderedDict([('section_id', 98), ('size_of_file', 5)]),
#  OrderedDict([('section_id', 99), ('size_of_file', 5)]),
#  OrderedDict([('section_id', 100), ('size_of_file', 6)]),
#  OrderedDict([('section_id', 101), ('size_of_file', 6)]),
#  OrderedDict([('section_id', 102), ('size_of_file', 6)]),
#  OrderedDict([('section_id', 103), ('size_of_file', 6)]),
#  OrderedDict([('section_id', 104), ('size_of_file', 6)]),
#  OrderedDict([('section_id', 105), ('size_of_file', 20)]),
#  OrderedDict([('section_id', 106), ('size_of_file', 20)]),
#  OrderedDict([('section_id', 107), ('size_of_file', 20)]),
#  OrderedDict([('section_id', 108), ('size_of_file', 20)]),
#  OrderedDict([('section_id', 109), ('size_of_file', 20)]),
#  OrderedDict([('section_id', 110), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 111), ('size_of_file', 20)]),
#  OrderedDict([('section_id', 112), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 113), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 114), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 115), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 116), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 117), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 118), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 119), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 120), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 121), ('size_of_file', 21)]),
#  OrderedDict([('section_id', 122), ('size_of_file', 14)]),
#  OrderedDict([('section_id', 123), ('size_of_file', 14)]),
#  OrderedDict([('section_id', 124), ('size_of_file', 14)]),
#  OrderedDict([('section_id', 125), ('size_of_file', 14)]),
#  OrderedDict([('section_id', 126), ('size_of_file', 29)]),
#  OrderedDict([('section_id', 127), ('size_of_file', 28)]),
#  OrderedDict([('section_id', 128), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 129), ('size_of_file', 36)]),
#  OrderedDict([('section_id', 130), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 132), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 133), ('size_of_file', 43)]),
#  OrderedDict([('section_id', 134), ('size_of_file', 51)]),
#  OrderedDict([('section_id', 135), ('size_of_file', 50)]),
#  OrderedDict([('section_id', 136), ('size_of_file', 51)]),
#  OrderedDict([('section_id', 137), ('size_of_file', 58)]),
#  OrderedDict([('section_id', 138), ('size_of_file', 44)])]

# %%
Shift.fetch(as_dict=True)
# Out:
# [OrderedDict([('section_id', 94), ('size_of_file', 4394)]),
#  OrderedDict([('section_id', 95), ('size_of_file', 4394)]),
#  OrderedDict([('section_id', 96), ('size_of_file', 4394)]),
#  OrderedDict([('section_id', 97), ('size_of_file', 4394)]),
#  OrderedDict([('section_id', 98), ('size_of_file', 4394)]),
#  OrderedDict([('section_id', 99), ('size_of_file', 4394)]),
#  OrderedDict([('section_id', 100), ('size_of_file', 4396)]),
#  OrderedDict([('section_id', 101), ('size_of_file', 4396)]),
#  OrderedDict([('section_id', 102), ('size_of_file', 4396)]),
#  OrderedDict([('section_id', 103), ('size_of_file', 4396)]),
#  OrderedDict([('section_id', 104), ('size_of_file', 4396)]),
#  OrderedDict([('section_id', 105), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 106), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 107), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 108), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 109), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 110), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 111), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 112), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 113), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 114), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 115), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 116), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 117), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 118), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 119), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 120), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 121), ('size_of_file', 14382)]),
#  OrderedDict([('section_id', 122), ('size_of_file', 9389)]),
#  OrderedDict([('section_id', 123), ('size_of_file', 9389)]),
#  OrderedDict([('section_id', 124), ('size_of_file', 9389)]),
#  OrderedDict([('section_id', 125), ('size_of_file', 9389)]),
#  OrderedDict([('section_id', 126), ('size_of_file', 19377)]),
#  OrderedDict([('section_id', 127), ('size_of_file', 19377)]),
#  OrderedDict([('section_id', 128), ('size_of_file', 29363)]),
#  OrderedDict([('section_id', 129), ('size_of_file', 24370)]),
#  OrderedDict([('section_id', 130), ('size_of_file', 29363)]),
#  OrderedDict([('section_id', 132), ('size_of_file', 29363)]),
#  OrderedDict([('section_id', 133), ('size_of_file', 29363)]),
#  OrderedDict([('section_id', 134), ('size_of_file', 34357)]),
#  OrderedDict([('section_id', 135), ('size_of_file', 34357)]),
#  OrderedDict([('section_id', 136), ('size_of_file', 34357)]),
#  OrderedDict([('section_id', 137), ('size_of_file', 36750)]),
#  OrderedDict([('section_id', 138), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 139), ('size_of_file', 42773)]),
#  OrderedDict([('section_id', 140), ('size_of_file', 44341)]),
#  OrderedDict([('section_id', 141), ('size_of_file', 49334)]),
#  OrderedDict([('section_id', 142), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 143), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 144), ('size_of_file', 41)]),
#  OrderedDict([('section_id', 145), ('size_of_file', 49)]),
#  OrderedDict([('section_id', 146), ('size_of_file', 49)]),
#  OrderedDict([('section_id', 147), ('size_of_file', 44)]),
#  OrderedDict([('section_id', 148), ('size_of_file', 49)]),
#  OrderedDict([('section_id', 149), ('size_of_file', 49)]),
#  OrderedDict([('section_id', 150), ('size_of_file', 54)]),
#  OrderedDict([('section_id', 152), ('size_of_file', 54)]),
#  OrderedDict([('section_id', 153), ('size_of_file', 54)]),
#  OrderedDict([('section_id', 154), ('size_of_file', 54)]),
#  OrderedDict([('section_id', 163), ('size_of_file', 49)])]

# %%
Shift.drop()
# Out:
# `kui_diffusionmap`.`__shift` (44 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.  Restart kernel.

# %%
! python Shift_datajoint.py 'local' 'MD594'
# Out:
# ./lib/utilities.py:14: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   credFiles = yaml.load(open( credential_file_pointers,'r'))
# Connecting kui@ucsd-demo-db.datajoint.io:3306
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ./lib/utilities.py:27: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   credFiles = yaml.load(open( credential_file_pointers,'r'))
# populating for  130
# run cmd= python /Users/kuiqian/Github/shapeology_code/scripts//Shape_shift.py MD594 130 shape_params.yaml
# /Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# /Users/kuiqian/Github/shapeology_code/scripts/lib/utils.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.D=yaml.load(open(yamlFile,'r'))
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC25-2015.08.26-16.43.04_MD594_2_0074_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC25-2015.08.26-16.43.04_MD594_2_0074_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC25-2015.08.26-16.43.04_MD594_2_0074_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC25-2015.08.26-16.43.04_MD594_2_0074_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_1_0076_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_1_0076_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_1_0076_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_1_0076_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_2_0077_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_2_0077_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_2_0077_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC26-2015.08.26-16.46.33_MD594_2_0077_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_1_0079_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_1_0079_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_1_0079_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_1_0079_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_2_0080_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_2_0080_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_2_0080_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC27-2015.08.26-16.50.00_MD594_2_0080_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_1_0082_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_1_0082_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_1_0082_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_1_0082_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_2_0083_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_2_0083_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_2_0083_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC28-2015.08.26-16.53.26_MD594_2_0083_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC29-2015.08.26-16.56.59_MD594_1_0085_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IHC29-2015.08.26-16.56.59_MD594_1_0085_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-IH
../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_shift/MD594/138.pkl to s3://mousebrainatlas-data/CSHL_shift/MD594/138.pkl
# populating for  139
# run cmd= python /Users/kuiqian/Github/shapeology_code/scripts//Shape_shift.py MD594 139 shape_params.yaml
# /Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# ALREADY DOWNLOADED FILE
# /Users/kuiqian/Github/shapeology_code/scripts/lib/utils.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.D=yaml.load(open(yamlFile,'r'))
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N27-2015.08.26-22.22.46_MD594_1_0079_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N27-2015.08.26-22.22.46_MD594_1_0079_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N27-2015.08.26-22.22.46_MD594_1_0079_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N27-2015.08.26-22.22.46_MD594_1_0079_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_1_0064_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_1_0064_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_1_0064_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_1_0064_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_2_0065_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_2_0065_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_2_0065_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N22-2015.08.26-22.05.55_MD594_2_0065_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_1_0067_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_1_0067_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_1_0067_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_1_0067_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_2_0068_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_2_0068_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_2_0068_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N23-2015.08.26-22.09.28_MD594_2_0068_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_1_0070_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_1_0070_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_1_0070_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_1_0070_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_2_0071_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_2_0071_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_2_0071_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N24-2015.08.26-22.12.42_MD594_2_0071_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N25-2015.08.26-22.16.07_MD594_2_0074_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N25-2015.08.26-22.16.07_MD594_2_0074_prep2_lossless_gray.tif
# download: s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N25-2015.08.26-22.16.07_MD594_2_0074_prep2_lossless_gray.tif to ../../../../BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N25-2015.08.26-22.16.07_MD594_2_0074_prep2_lossless_gray.tif
# run cmd= aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N26-2015.08.26-22.19.23_MD594_1_0076_prep2_lossless_gray.tif /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_data_processed/MD594/MD594_prep2_lossless_gray/MD594-N26-2015.08.26-22.19.23_MD594_1_0076_prep2_lossless_gray.tif
# ^Cmpleted 120.5 MiB/182.3 MiB (8.2 MiB/s) with 1 file(s) remaining
# Completed 122.0 MiB/182.3 MiB (8.2 MiB/s) with 1 file(s) remaining

# %%
schema.size_on_disk
# Out:
# 65536

# %%
schema.connection.close()

# %%
schema.drop('kui_diffusionmap')

# %%
schema.log
# Out:
# *timestamp     version      user           host           event
# +------------+ +----------+ +------------+ +------------+ +------------+
# 2019-07-18 06: 0.11.2py     kui@76.176.26. Kuis-MacBook-P DELETE FROM `k
#  (Total: 1)
