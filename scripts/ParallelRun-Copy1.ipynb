# %%
! python Cell_generator.py MD589 2 'shape_params-aws.yaml'
# Out:
# 2019-05-17 11:27:26,542	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_11-27-26_30871/logs.
# 2019-05-17 11:27:26,649	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:53137 to respond...
# 2019-05-17 11:27:26,759	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:13678 to respond...
# 2019-05-17 11:27:26,760	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 11:27:26,772	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_11-27-26_30871/logs.
# 2019-05-17 11:27:26,773	WARNING services.py:1304 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 36878782464 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# 2019-05-17 11:27:26,773	INFO services.py:1427 -- Starting the Plasma object store with 70.0 GB memory using /tmp.
# /data/Github/shapeology_code/scripts/lib/utils.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.D=yaml.load(open(yamlFile,'r'))
# /data/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/
# (pid=31465) 7N 26
# (pid=31466) 7n 25
# (pid=31465) 7N 20023
# (pid=31466) 7n 20009
# (pid=31465) 7N 40003
# (pid=31466) 7n 40030
# (pid=31465) 7N 60018
# (pid=31465) 7N 80021
# (pid=31466) 7n 60009
# (pid=31466) 7n 60027
# (pid=31465) 7N 100026
# (pid=31465) 7N 2935 21075
# (pid=31466) 7n 80008
# (pid=31465) 7N 120002
# (pid=31465) 7N 140028
# (pid=31466) 7n 100020
# (pid=31466) 7n 6265 7328
# (pid=31465) 7N 160011
# (pid=31466) 7n 117142
# (pid=31466) 7n_positive finished in 2040.8 seconds
# (pid=31466) 7n 17
# 2019-05-17 12:01:32,033	ERROR worker.py:1609 -- Possible unhandled error from worker: ray_worker:__main__.generator() (pid=31465, host=ip-172-31-29-217)
#   File "Cell_generator.py", line 62, in generator
#     extracted= extractor.extract_blobs(Stats,tile)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 115, in extract_blobs
#     self.computeDMs(extracted)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 151, in computeDMs
#     DMMat=self.DM.transform(asMat)
#   File "/data/Github/shapeology_code/scripts/label_patch.py", line 33, in transform
#     lowD=self.DM.transform(data1D)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 247, in transform
#     return nystroem_oos(self, Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 312, in nystroem_oos
#     kernel_extended = dmap_object.local_kernel.compute(Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 158, in compute
#     K = self._get_scaled_distance_mat(Y, y_bandwidths=y_bandwidths)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 168, in _get_scaled_distance_mat
#     dists = self.neigh.kneighbors_graph(Y, mode='distance')
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 548, in kneighbors_graph
#     X, n_neighbors, return_distance=True)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 443, in kneighbors
#     for s in gen_even_slices(X.shape[0], n_jobs)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 983, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 222, in apply_async
#     return self._get_pool().apply_async(
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 363, in _get_pool
#     self._pool = ThreadPool(self._n_jobs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 828, in __init__
#     Pool.__init__(self, processes, initializer, initargs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 177, in __init__
#     self._repopulate_pool()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 238, in _repopulate_pool
#     self._wrap_exception)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 257, in _repopulate_pool_static
#     w.start()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/dummy/__init__.py", line 51, in start
#     threading.Thread.start(self)
#   File "/home/ubuntu/anaconda3/lib/python3.7/threading.py", line 847, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# (pid=31466) 7n 20024
# (pid=31466) 7n 40016
# (pid=31466) 7n 60012
# (pid=31466) 7n 80011
# (pid=31466) 7n 100003
# (pid=31466) 7n 4939 50627
# (pid=31466) 7n 120011
# Traceback (most recent call last):
#   File "Cell_generator.py", line 107, in <module>
#     ray.get([generator.remote(structure, cell_dir, patch_dir, stack, params) for structure in all_structures[(seq-1)*2:seq*2]])
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 2184, in get
#     raise value
# ray.exceptions.RayTaskError: ray_worker:__main__.generator() (pid=31465, host=ip-172-31-29-217)
#   File "Cell_generator.py", line 62, in generator
#     extracted= extractor.extract_blobs(Stats,tile)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 115, in extract_blobs
#     self.computeDMs(extracted)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 151, in computeDMs
#     DMMat=self.DM.transform(asMat)
#   File "/data/Github/shapeology_code/scripts/label_patch.py", line 33, in transform
#     lowD=self.DM.transform(data1D)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 247, in transform
#     return nystroem_oos(self, Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 312, in nystroem_oos
#     kernel_extended = dmap_object.local_kernel.compute(Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 158, in compute
#     K = self._get_scaled_distance_mat(Y, y_bandwidths=y_bandwidths)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 168, in _get_scaled_distance_mat
#     dists = self.neigh.kneighbors_graph(Y, mode='distance')
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 548, in kneighbors_graph
#     X, n_neighbors, return_distance=True)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 443, in kneighbors
#     for s in gen_even_slices(X.shape[0], n_jobs)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 983, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 222, in apply_async
#     return self._get_pool().apply_async(
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 363, in _get_pool
#     self._pool = ThreadPool(self._n_jobs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 828, in __init__
#     Pool.__init__(self, processes, initializer, initargs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 177, in __init__
#     self._repopulate_pool()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 238, in _repopulate_pool
#     self._wrap_exception)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 257, in _repopulate_pool_static
#     w.start()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/dummy/__init__.py", line 51, in start
#     threading.Thread.start(self)
#   File "/home/ubuntu/anaconda3/lib/python3.7/threading.py", line 847, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread

# %%
! python Cell_generator.py MD589 6 'shape_params-aws.yaml'
# Out:
# 2019-05-17 12:40:43,001	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_12-40-42_22839/logs.
# 2019-05-17 12:40:43,108	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:58832 to respond...
# 2019-05-17 12:40:43,222	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:58960 to respond...
# 2019-05-17 12:40:43,223	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 12:40:43,235	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_12-40-42_22839/logs.
# 2019-05-17 12:40:43,235	WARNING services.py:1304 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 36878782464 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# 2019-05-17 12:40:43,235	INFO services.py:1427 -- Starting the Plasma object store with 70.0 GB memory using /tmp.
# /data/Github/shapeology_code/scripts/lib/utils.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.D=yaml.load(open(yamlFile,'r'))
# /data/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/
# (pid=24102) SNC_positive ALREADY EXIST
# (pid=24102) SNC 20015
# (pid=24115) RMC 20001
# (pid=24102) SNC 40027
# (pid=24115) RMC 40008
# (pid=24102) SNC 60004
# (pid=24115) RMC 60013
# (pid=24102) SNC 80023
# (pid=24115) RMC 80025
# 2019-05-17 12:58:23,898	ERROR worker.py:1609 -- Possible unhandled error from worker: ray_worker:__main__.generator() (pid=24102, host=ip-172-31-29-217)
#   File "Cell_generator.py", line 62, in generator
#     extracted= extractor.extract_blobs(Stats,tile)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 115, in extract_blobs
#     self.computeDMs(extracted)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 151, in computeDMs
#     DMMat=self.DM.transform(asMat)
#   File "/data/Github/shapeology_code/scripts/label_patch.py", line 33, in transform
#     lowD=self.DM.transform(data1D)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 247, in transform
#     return nystroem_oos(self, Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 312, in nystroem_oos
#     kernel_extended = dmap_object.local_kernel.compute(Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 158, in compute
#     K = self._get_scaled_distance_mat(Y, y_bandwidths=y_bandwidths)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 168, in _get_scaled_distance_mat
#     dists = self.neigh.kneighbors_graph(Y, mode='distance')
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 548, in kneighbors_graph
#     X, n_neighbors, return_distance=True)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 443, in kneighbors
#     for s in gen_even_slices(X.shape[0], n_jobs)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 983, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 222, in apply_async
#     return self._get_pool().apply_async(
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 363, in _get_pool
#     self._pool = ThreadPool(self._n_jobs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 828, in __init__
#     Pool.__init__(self, processes, initializer, initargs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 177, in __init__
#     self._repopulate_pool()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 238, in _repopulate_pool
#     self._wrap_exception)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 257, in _repopulate_pool_static
#     w.start()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/dummy/__init__.py", line 51, in start
#     threading.Thread.start(self)
#   File "/home/ubuntu/anaconda3/lib/python3.7/threading.py", line 847, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
#
# (pid=24115) RMC 100002
# (pid=24115) RMC 3350 8210
# (pid=24115) RMC 100020
# (pid=24115) RMC 120029
# (pid=24115) RMC 140003
# (pid=24115) RMC 140019
# (pid=24115) RMC 160005
# (pid=24115) RMC 160026
# (pid=24115) RMC 180024
# (pid=24115) RMC 200013
# (pid=24115) RMC 220022
# (pid=24115) RMC 227671
# (pid=24115) RMC_positive finished in 3285.0 seconds
# (pid=24115) RMC 20024
# (pid=24115) RMC 40025
# (pid=24115) RMC 60010
# (pid=24115) RMC 80005
# (pid=24115) RMC 100022
# (pid=24115) RMC 3052 30511
# (pid=24115) RMC 120029
# (pid=24115) RMC 140025
# (pid=24115) RMC 180026
# (pid=24115) RMC 200009
# (pid=24115) RMC 220017
# (pid=24115) RMC 240016
# (pid=24115) RMC 260014
# (pid=24115) RMC 280023
# Traceback (most recent call last):
#   File "Cell_generator.py", line 107, in <module>
#     ray.get([generator.remote(structure, cell_dir, patch_dir, stack, params) for structure in all_structures[(seq-1)*2:seq*2]])
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 2184, in get
#     raise value
# ray.exceptions.RayTaskError: ray_worker:__main__.generator() (pid=24115, host=ip-172-31-29-217)
#   File "Cell_generator.py", line 62, in generator
#     extracted= extractor.extract_blobs(Stats,tile)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 115, in extract_blobs
#     self.computeDMs(extracted)
#   File "/data/Github/shapeology_code/scripts/extractPatches.py", line 151, in computeDMs
#     DMMat=self.DM.transform(asMat)
#   File "/data/Github/shapeology_code/scripts/label_patch.py", line 33, in transform
#     lowD=self.DM.transform(data1D)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 247, in transform
#     return nystroem_oos(self, Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/diffusion_map.py", line 312, in nystroem_oos
#     kernel_extended = dmap_object.local_kernel.compute(Y)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 158, in compute
#     K = self._get_scaled_distance_mat(Y, y_bandwidths=y_bandwidths)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/pydiffmap/kernel.py", line 168, in _get_scaled_distance_mat
#     dists = self.neigh.kneighbors_graph(Y, mode='distance')
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 548, in kneighbors_graph
#     X, n_neighbors, return_distance=True)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/neighbors/base.py", line 443, in kneighbors
#     for s in gen_even_slices(X.shape[0], n_jobs)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 983, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 222, in apply_async
#     return self._get_pool().apply_async(
#   File "/data/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 363, in _get_pool
#     self._pool = ThreadPool(self._n_jobs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 828, in __init__
#     Pool.__init__(self, processes, initializer, initargs)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 177, in __init__
#     self._repopulate_pool()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 238, in _repopulate_pool
#     self._wrap_exception)
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/pool.py", line 257, in _repopulate_pool_static
#     w.start()
#   File "/home/ubuntu/anaconda3/lib/python3.7/multiprocessing/dummy/__init__.py", line 51, in start
#     threading.Thread.start(self)
#   File "/home/ubuntu/anaconda3/lib/python3.7/threading.py", line 847, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread

# %%
! python Cell_generator.py MD589 8 'shape_params-aws.yaml'
# Out:
# 2019-05-17 15:14:26,931	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_15-14-26_7641/logs.
# 2019-05-17 15:14:27,039	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:52342 to respond...
# 2019-05-17 15:14:27,151	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:55033 to respond...
# 2019-05-17 15:14:27,152	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 15:14:27,163	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_15-14-26_7641/logs.
# 2019-05-17 15:14:27,164	WARNING services.py:1304 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 36878782464 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# 2019-05-17 15:14:27,164	INFO services.py:1427 -- Starting the Plasma object store with 70.0 GB memory using /tmp.
# /data/Github/shapeology_code/scripts/lib/utils.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.D=yaml.load(open(yamlFile,'r'))
# /data/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/
# (pid=7756) 4N 23
# (pid=7756) 4N 1833
# (pid=7756) 4N_positive finished in  23.0 seconds
# (pid=7756) 4N 30
# (pid=7776) Sp5I 20020
# (pid=7756) 4N 20010
# (pid=7776) Sp5I 40017
# (pid=7756) 4N 40019
# (pid=7776) Sp5I 60009
# (pid=7756) 4N 60009
# (pid=7776) Sp5I 80028
# (pid=7756) 4N 80027
# (pid=7776) Sp5I 100030
# (pid=7776) Sp5I 2601 37163
# (pid=7756) 4N 86288
# (pid=7756) 4N_negative finished in 1012.0 seconds
# (pid=7756) 4N finished in 1035.1 seconds
# (pid=7776) Sp5I 180014
# (pid=7776) Sp5I 200027
# (pid=7776) Sp5I 240021
# (pid=7776) Sp5I 260026
# (pid=7776) Sp5I 300001
# (pid=7776) Sp5I 320025
# (pid=7776) Sp5I 340011
# (pid=7776) Sp5I 360003
# (pid=7776) Sp5I 380004
# (pid=7776) Sp5I 400027
# (pid=7776) Sp5I 420010
# (pid=7776) Sp5I 440025
# (pid=7776) Sp5I 460013
# (pid=7776) Sp5I 480010
# (pid=7776) Sp5I 500026
# (pid=7776) Sp5I 540023
# (pid=7776) Sp5I 560015
# (pid=7776) Sp5I 580004
# (pid=7776) Sp5I 600029
# (pid=7776) Sp5I 620003
# (pid=7776) Sp5I 640028
# (pid=7776) Sp5I 660001
# (pid=7776) Sp5I 680017
# (pid=7776) Sp5I 700024
# (pid=7776) Sp5I 720007
# (pid=7776) Sp5I 740000
# (pid=7776) Sp5I 780004
# (pid=7776) Sp5I 800023
# (pid=7776) Sp5I 820022
# (pid=7776) Sp5I 840004
# (pid=7776) Sp5I 860002
# (pid=7776) Sp5I 880025
# (pid=7776) Sp5I 920019
# (pid=7776) Sp5I 940006

# %%
import ray
ray.shutdown()
ray.init(object_store_memory=70000000000,redis_max_memory=30000000000)
# Out:
# 2019-05-17 10:23:27,353	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_10-23-27_23308/logs.
# 2019-05-17 10:23:27,459	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:40289 to respond...
# 2019-05-17 10:23:27,567	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:53403 to respond...
# 2019-05-17 10:23:27,569	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 10:23:27,578	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_10-23-27_23308/logs.
# 2019-05-17 10:23:27,579	WARNING services.py:1304 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 36878782464 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# 2019-05-17 10:23:27,580	INFO services.py:1427 -- Starting the Plasma object store with 70.0 GB memory using /tmp.
# {'node_ip_address': '172.31.29.217',
#  'redis_address': '172.31.29.217:40289',
#  'object_store_address': '/tmp/ray/session_2019-05-17_10-23-27_23308/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-05-17_10-23-27_23308/sockets/raylet',
#  'webui_url': None}

# %%
import os
stack='MD589'
cell_dir = os.environ['ROOT_DIR']+'CSHL_cells_dm/'+stack+'/'
cell_dir
# Out:
# '/data/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/'

# %%
! aws s3 cp --recursive $cell_dir s3://mousebrainatlas-data/CSHL_cells_dm/MD589/
# Out:
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/4N/MD589_4N_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/4N/MD589_4N_positive.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/4N/MD589_4N_negative.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/4N/MD589_4N_negative.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/3N/MD589_3N_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/3N/MD589_3N_positive.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/6N/MD589_6N_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/6N/MD589_6N_positive.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/5N/MD589_5N_negative_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/5N/MD589_5N_negative_part.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/6N/MD589_6N_negative.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/6N/MD589_6N_negative.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/7n/MD589_7n_negative_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/7n/MD589_7n_negative_part.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/7N/MD589_7N_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/7N/MD589_7N_positive_part.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/7n/MD589_7n_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/7n/MD589_7n_positive.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/Amb/MD589_Amb_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/Amb/MD589_Amb_positive.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/Amb/MD589_Amb_negative_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/Amb/MD589_Amb_negative_part.pkliB/~85.4 GiB (238.7 MiB/s) with ~6 file(s) remaining (calculating...)ith ~6 file(s) remaining (calculating...)mpleted 59.8 GiB/~85.4 GiB (238.6 MiB/s) with ~6 file(s) remaining (calculating...)
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/Amb/MD589_Amb_negative.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/Amb/MD589_Amb_negative.pkl ~6 file(s) remaining (calculating...).4 GiB (238.4 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...)ith ~6 file(s) remaining (calculating...)mpleted 67.0 GiB/~91.4 GiB (238.4 MiB/s) with ~6 file(s) remaining (calculating...).4 GiB (238.4 MiB/s) with ~6 file(s) remaining (calculating...).4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...).4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...).4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...).4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...).4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...).4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...)ith ~6 file(s) remaining (calculating...)mpleted 71.4 GiB/~91.4 GiB (238.3 MiB/s) with ~6 file(s) remaining (calculating...)
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/5N/MD589_5N_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/5N/MD589_5N_positive.pkl GiB (238.2 MiB/s) with ~5 file(s) remaining (calculating...) (calculating...)iB (238.2 MiB/s) with ~5 file(s) remaining (calculating...)calculating...) (238.2 MiB/s) with ~5 file(s) remaining (calculating...)ith ~5 file(s) remaining (calculating...)mpleted 74.6 GiB/~91.4 GiB (238.1 MiB/s) with ~5 file(s) remaining (calculating...)ith ~5 file(s) remaining (calculating...)mpleted 74.9 GiB/~91.4 GiB (238.1 MiB/s) with ~5 file(s) remaining (calculating...)ith ~6 file(s) remaining (calculating...)mpleted 75.9 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ith ~6 file(s) remaining (calculating...)mpleted 76.0 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) (calculating...)iB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)calculating...) (238.1 MiB/s) with ~6 file(s) remaining (calculating...)lculating...)238.1 MiB/s) with ~6 file(s) remaining (calculating...)ulating...)e(s) remaining (calculating...).9 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)s) remaining (calculating...) GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) remaining (calculating...)iB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) (calculating...)~6 file(s) remaining (calculating...)ted 77.1 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) file(s) remaining (calculating...)d 77.1 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ile(s) remaining (calculating...)77.1 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)e(s) remaining (calculating...).1 GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)s) remaining (calculating...) GiB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...) remaining (calculating...)iB/~95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)emaining (calculating...)aining (calculating...)95.6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.1 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.0 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.0 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.0 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.0 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.0 MiB/s) with ~6 file(s) remaining (calculating...).6 GiB (238.0 MiB/s) with ~6 file(s) remaining (calculating...)ng (calculating...) GiB (238.0 MiB/s) with ~6 file(s) remaining (calcul ...
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/3N/MD589_3N_negative.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/3N/MD589_3N_negative.pklulating...)g (calculating...)ing (calculating...)ining (calculating...)maining (calculating...)remaining (calculating...)) remaining (calculating...)(s) remaining (calculating...)le(s) remaining (calculating...)file(s) remaining (calculating...)7 file(s) remaining (calculating...) ~7 file(s) remaining (calculating...))..)g...)ing...))..)ing...)g...).).)...).)...)ng...)ting...)lating...)culating...)alculating...)(calculating...)g (calculating...)ning (calculating...)aining (calculating...)remaining (calculating...)s) remaining (calculating...)e(s) remaining (calculating...)ile(s) remaining (calculating...)7 file(s) remaining (calculating...).).)...)ng...)ting...)lating...)culating...)alculating...)(calculating...)g (calculating...)ing (calculating...)ining (calculating...)maining (calculating...)remaining (calculating...)) remaining (calculating...)(s) remaining (calculating...)le(s) remaining (calculating...)file(s) remaining (calculating...)7 file(s) remaining (calculating...) ~7 file(s) remaining (calculating...)th ~7 file(s) remaining (calculating...)with ~7 file(s) remaining (calculating...)) with ~7 file(s) remaining (calculating...)/s) with ~7 file(s) remaining (calculating...)iB/s) with ~7 file(s) remaining (calculating...) MiB/s) with ~7 file(s) remaining (calculating...).8 MiB/s) with ~7 file(s) remaining (calculating...))..)g...)ing...))..)g...)ing...))..)g...)ing...)...).)ing...)..)ng...)ulating...).).).)...)ng...)ting...).)...)ng...)ting...)ulating...).)...)ng...)ting...)lating...)culating...)alculating...)(calculating...)g (calculating...)ing (calculating...)ining (calculating...)maining (calculating...)remaining (calculating...)) remaining (calculating...)(s) remaining (calculating...)le(s) remaining (calculating...)file(s) remaining (calculating...)8 file(s) remaining (calculating...) ~8 file(s) remaining (calculating...)th ~8 file(s) remaining (calculating...)with ~8 file(s) remaining (calculating...)) with ~8 file(s) remaining (calculating...)/s) with ~8 file(s) remaining (calculating...)iB/s) with ~8 file(s) remaining (calculating...) MiB/s) with ~8 file(s) remaining (calculating...).8 MiB/s) with ~8 file(s) remaining (calculating...)37.8 MiB/s) with ~8 file(s) remaining (calculating...)(237.8 MiB/s) with ~8 file(s) remaining (calculating...)B (237.8 MiB/s) with ~8 file(s) remaining (calculating...)GiB (237.8 MiB/s) with ~8 file(s) remaining (calculating...)8 GiB (237.8 MiB/s) with ~8 file(s) remaining (calculating...))..)g...)ing...)ating...)ulating...)lculating...)calculating...)g (calculating...)ing (calculating...)ining (calculating...).)...)ng...)..)g...)ing...)..)ing...))...)ng...)ting...)..)g...))...)ng...)lating...)culating...)calculating...) (calculating...)ng (calculating...)ning (calculating...)aining (calculating...)remaining (calculating...)s) remaining (calculating...)e(s) remaining (calculating...)file(s) remaining (calculating...)8 file(s) remaining (calculating...) ~8 file(s) remaining (calculating...)th ~8 file(s) remaining (calculating...)with ~8 file(s) remaining (calculating...)) with ~8 file(s) remaining (calculating...)/s) with ~8 file(s) remaining (calculating...)iB/s) with ~8 file(s) remaining (calculating...) MiB/s) with ~8 file(s) remaining (calculating...).7 MiB/s) with ~8 file(s) remaining (calculating...)37.7 MiB/s) with ~8 file(s) remaining (calculating...)(237.7 MiB/s) with ~8 file(s) remaining (calculating...)B (237.7 MiB/s) with ~8 file(s) remaining (calculating...)GiB (237.7 MiB/s) with ~8 file(s) remaining (calculating...)8 GiB (237.7 MiB/s) with ~8 file(s) remaining (calculating...)3.8 GiB (237.7 MiB/s) with ~8 file(s) remaining (calculating...)113.8 GiB (237.7 MiB/s) with ~8 file(s) remaining (calculating...)/~113.8 GiB (237.7 MiB/s) with ~8 file(s) remaining (calculating...)iB/~113.8 GiB (237.7 MiB/s) with  ...
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/LC/MD589_LC_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/LC/MD589_LC_positive.pkl)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/LC/MD589_LC_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/LC/MD589_LC_positive_part.pklng...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/Pn/MD589_Pn_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/Pn/MD589_Pn_positive_part.pkl.)ing...))..)g...)ing...).)...)ng...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...))..)g...)ing...).)...)ng...))..)g...)ing...).)...)ng...))..)g...)ing...)..)).)B/s) with ~7 file(s) remaining (calculating...)GiB/~122.2 GiB (238.1 MiB/s) with ~7 file(s) remaining (calculating...)ing...)e(s) remaining (calculating...)238.1 MiB/s) with ~7 file(s) remaining (calculating...)d 100.3 GiB/~122.2 GiB (238.1 MiB/s) with ~7 file(s) remaining (calculating...)calculating...)h ~7 file(s) remaining (calculating...)/s) with 8 file(s) remaining                   ning                   /s) with 8 file(s) remaining                   GiB/126.1 GiB (238.1 MiB/s) with 8 file(s) remaining                          s) remaining                   38.1 MiB/s) with 8 file(s) remaining                   d 100.8 GiB/126.1 GiB (238.1 MiB/s) with 8 file(s) remaining                                   8 file(s) remaining                   1 GiB (238.1 MiB/s) with 8 file(s) remaining                   ning                   /s) with 8 file(s) remaining                   ning                   ning                   GiB/126.1 GiB (238.1 MiB/s) with 8 file(s) remaining                   s) remaining                   38.1 MiB/s) with 8 file(s) remaining                   ning                   /s) with 8 file(s) remaining
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/RMC/MD589_RMC_negative_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/RMC/MD589_RMC_negative_part.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/SNC/MD589_SNC_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/SNC/MD589_SNC_positive.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/RMC/MD589_RMC_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/RMC/MD589_RMC_positive_part.pkl(s) remaininge(s) remainingle(s) remainingile(s) remainingfile(s) remaininggngingningaininggnggggngingninggngingninginingainingmainingemainingremaining remaining) remaining
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/SNR/MD589_SNR_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/SNR/MD589_SNR_positive_part.pklngninginingainingmainingemaininggngingninginingainingmainingggngingggingninginingngingainingmainingemainingremaining) remainings) remaining(s) remaininge(s) remainingle(s) remainingile(s) remainingfile(s) remaining file(s) remaining4 file(s) remaining 4 file(s) remainingh 4 file(s) remainingth 4 file(s) remainingith 4 file(s) remainingwith 4 file(s) remaining with 4 file(s) remaininggngingninginingainingmainingemaininggngingninginingemainingmainingmainingnggngaininggngingninginingainingremaininggngingninginingainingmainingemainingremaining remaining) remainings) remaining(s) remaininge(s) remainingle(s) remainingile(s) remainingfile(s) ...
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/VLL/MD589_VLL_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/VLL/MD589_VLL_positive_part.pklGiB (237.9 MiB/s) with 3 file(s) remainingningainingningainingmaininginginginingmainingningemainingngaininginingginingainingingainingingemaininginggingmainingininggngninginingngingningainingremaining) remaininggnginingmainingemainingngningginginingainingmainingemainingremaining remaining) remainings) remaining(s) remaininge(s) remainingle(s) remainingile(s) remainingfile(s) remaining file(s) remaining3 file(s) remaining 3 file(s) remainingh 3 file(s) ...
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/Sp5I/MD589_Sp5I_positive_part.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/Sp5I/MD589_Sp5I_positive_part.pkl
# upload: ../../../BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/RMC/MD589_RMC_positive.pkl to s3://mousebrainatlas-data/CSHL_cells_dm/MD589/RMC/MD589_RMC_positive.pklB/126.1 GiB (238.0 MiB/s) with 1 file(s) remaining6 GiB/126.1 GiB (238.0 MiB/s) with 1 file(s) remaining.6 GiB/126.1 GiB (238.0 MiB/s) with 1 file(s) remaining3.6 GiB/126.1 GiB (238.0 MiB/s) with 1 file(s) remaining23.6 GiB/126.1 GiB (238.0 MiB/s) with 1 file(s) ...
