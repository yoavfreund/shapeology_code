# %%
! python Cell_generator.py MD589 3 'shape_params-aws.yaml'
# Out:
# 2019-05-17 11:27:36,174	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_11-27-36_2816/logs.
# 2019-05-17 11:27:36,281	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:54692 to respond...
# 2019-05-17 11:27:36,391	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:56748 to respond...
# 2019-05-17 11:27:36,392	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 11:27:36,403	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_11-27-36_2816/logs.
# ...

# %%
! python Cell_generator.py MD589 5 'shape_params-aws.yaml'
# Out:
# 2019-05-17 12:17:24,414	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_12-17-24_567/logs.
# 2019-05-17 12:17:24,520	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:31339 to respond...
# 2019-05-17 12:17:24,630	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:44125 to respond...
# 2019-05-17 12:17:24,631	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 12:17:24,644	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_12-17-24_567/logs.
# ...

# %%
import ray
ray.shutdown()
ray.init(object_store_memory=70000000000,redis_max_memory=30000000000)
# Out:
# 2019-05-17 10:23:27,353	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_10-23-27_23308/logs.
# 2019-05-17 10:23:27,459	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:40289 to respond...
# 2019-05-17 10:23:27,567	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:53403 to respond...
# 2019-05-17 10:23:27,569	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 10:23:27,578	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_10-23-27_23308/logs.
# ...
