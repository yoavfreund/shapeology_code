# %%
! python Cell_generator.py MD589 'shape_params.yaml'
# Out:
# /Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# 2019-05-17 00:54:12,883	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_00-54-12_10655/logs.
# 2019-05-17 00:54:12,994	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:11635 to respond...
# 2019-05-17 00:54:13,118	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:34853 to respond...
# 2019-05-17 00:54:13,121	INFO services.py:804 -- Starting Redis shard with 1.72 GB max memory.
# 2019-05-17 00:54:13,133	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_00-54-12_10655/logs.
# 2019-05-17 00:54:13,134	INFO services.py:1427 -- Starting the Plasma object store with 2.58 GB memory using /tmp.
# /Users/kuiqian/Github/shapeology_code/scripts/lib/utils.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.D=yaml.load(open(yamlFile,'r'))
# /Users/kuiqian/BstemAtlasDataBackup/ucsd_brain/CSHL_cells_dm/MD589/
# (pid=10668) 6N_positive ALREADY EXIST
# (pid=10668) 6N_negative ALREADY EXIST
# (pid=10668) 6N finished in   0.0 seconds
# (pid=10669) 5N 26
# (pid=10667) 7n 28
# (pid=10670) 7N 28
# (pid=10670) 7N 1007
# (pid=10667) 7n 1007
# (pid=10669) 5N 1013
# (pid=10668) Amb 1012
# (pid=10667) 7n 2013
# (pid=10670) 7N 2013
# (pid=10669) 5N 2002
# (pid=10668) Amb 2006
# ^C
# Traceback (most recent call last):
#   File "Cell_generator.py", line 105, in <module>
#     ray.get([generator.remote(structure, cell_dir, patch_dir, stack, params) for structure in all_structures])
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 2180, in get
#     values = worker.get_object(object_ids)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 541, in get_object
#     int(0.01 * len(unready_ids)),
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 415, in retrieve_and_deserialize
#     with_meta=True,
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/utils.py", line 475, in _wrapper
#     return orig_attr(*args, **kwargs)
#   File "pyarrow/_plasma.pyx", line 389, in pyarrow._plasma.PlasmaClient.get_buffers
#   File "pyarrow/_plasma.pyx", line 285, in pyarrow._plasma.PlasmaClient._get_object_buffers
#   File "pyarrow/error.pxi", line 79, in pyarrow.lib.check_status
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/compat.py", line 109, in frombytes
#     def frombytes(o):
# KeyboardInterrupt
# Exception in thread ray_import_thread:
# Traceback (most recent call last):
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/import_thread.py", line 70, in _run
#     msg = import_pubsub_client.get_message()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
# Exception in thread ray_print_logs:
# Traceback (most recent call last):
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 1547, in print_logs
#     msg = pubsub_client.get_message()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
#
# Exception in thread ray_listen_error_messages:
# Traceback (most recent call last):
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/ray/worker.py", line 1650, in listen_error_messages_raylet
#     msg = worker.error_message_pubsub_client.get_message()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)

# %%
import ray
ray.init()
# Out:
# 2019-05-17 00:00:28,903	WARNING worker.py:1337 -- WARNING: Not updating worker name since `setproctitle` is not installed. Install this with `pip install setproctitle` (or ray[debug]) to enable monitoring of worker processes.
# 2019-05-17 00:00:28,905	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_00-00-28_10091/logs.
# 2019-05-17 00:00:29,016	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:59072 to respond...
# 2019-05-17 00:00:29,147	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:56620 to respond...
# 2019-05-17 00:00:29,152	INFO services.py:804 -- Starting Redis shard with 1.72 GB max memory.
# 2019-05-17 00:00:29,167	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_00-00-28_10091/logs.
# 2019-05-17 00:00:29,171	INFO services.py:1427 -- Starting the Plasma object store with 2.58 GB memory using /tmp.
# {'node_ip_address': '100.83.10.77',
#  'redis_address': '100.83.10.77:59072',
#  'object_store_address': '/tmp/ray/session_2019-05-17_00-00-28_10091/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-05-17_00-00-28_10091/sockets/raylet',
#  'webui_url': None}

# %%
paired_structures = ['5N', '6N', '7N', '7n', 'Amb', 'LC', 'LRt', 'Pn', 'Tz', 'VLL', 'RMC', \
                     'SNC', 'SNR', '3N', '4N', 'Sp5I', 'Sp5O', 'Sp5C', 'PBG', '10N', 'VCA', 'VCP', 'DC']
singular_structures = ['AP', '12N', 'RtTg', 'SC', 'IC']

all_structures = paired_structures + singular_structures
