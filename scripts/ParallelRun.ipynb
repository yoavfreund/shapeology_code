# %%
import sys
import os

def setup_download_from_s3( rel_fp, recursive=True ):
    s3_fp = 's3://mousebrainatlas-data/'+rel_fp
    local_fp = os.environ['ROOT_DIR']+rel_fp

    if os.path.exists(local_fp):
        print('ALREADY DOWNLOADED FILE')
        return 
    
    if recursive:
        ! aws s3 cp --recursive $s3_fp $local_fp
    else:
        ! aws s3 cp $s3_fp $local_fp

# %%
setup_download_from_s3('CSHL_cells_dm/MD589/')
# Out:
# ALREADY DOWNLOADED FILE

# %%
! python Cell_generator.py MD589 5N positive 'shape_params.yaml'
# Out:
# /Users/kuiqian/Github/venv/shapeology_venv/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# 2019-05-30 17:49:08,701	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-30_17-49-08_24615/logs.
# 2019-05-30 17:49:08,809	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:46840 to respond...
# 2019-05-30 17:49:08,929	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:29083 to respond...
# 2019-05-30 17:49:08,932	INFO services.py:804 -- Starting Redis shard with 1.72 GB max memory.
# 2019-05-30 17:49:08,944	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-30_17-49-08_24615/logs.
# 2019-05-30 17:49:08,944	INFO services.py:1427 -- Starting the Plasma object store with 2.58 GB memory using /tmp.
# ...

# %%
! python Cell_generator.py MD589 13 'shape_params-aws.yaml'
# Out:
# 2019-05-24 08:48:36,766	WARNING worker.py:1341 -- WARNING: Not updating worker name since `setproctitle` is not installed. Install this with `pip install setproctitle` (or ray[debug]) to enable monitoring of worker processes.
# 2019-05-24 08:48:36,768	INFO node.py:497 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-24_08-48-36_766955_28622/logs.
# 2019-05-24 08:48:36,876	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:18893 to respond...
# 2019-05-24 08:48:36,986	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:53148 to respond...
# 2019-05-24 08:48:36,987	INFO services.py:806 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-24 08:48:36,999	INFO node.py:511 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-24_08-48-36_766955_28622/logs.
# ...

# %%
! python Cell_generator.py MD589 7 'shape_params-aws.yaml'
# Out:
# 2019-05-17 13:29:38,489	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_13-29-38_32999/logs.
# 2019-05-17 13:29:38,596	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:64804 to respond...
# 2019-05-17 13:29:38,707	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:13554 to respond...
# 2019-05-17 13:29:38,708	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 13:29:38,720	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_13-29-38_32999/logs.
# ...

# %%
import ray
ray.shutdown()
ray.init(object_store_memory=70000000000,redis_max_memory=30000000000)
# Out:
# 2019-05-17 10:23:27,353	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_10-23-27_23308/logs.
# 2019-05-17 10:23:27,459	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:40289 to respond...
# 2019-05-17 10:23:27,567	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:53403 to respond...
# 2019-05-17 10:23:27,569	INFO services.py:804 -- Starting Redis shard with 30.0 GB max memory.
# 2019-05-17 10:23:27,578	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-05-17_10-23-27_23308/logs.
# ...
